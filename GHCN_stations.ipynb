# %%
# import the dependencies

import os
import pandas as pd

# Import SQL Alchemy
from sqlalchemy import create_engine

# Import and establish Base for which classes will be constructed 
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# Import modules to declare columns and column data types
from sqlalchemy import Column, Integer, String, Float, ForeignKey
from sqlalchemy.orm import relationship

# %%
# Pull in our GCHN_archive class

# %%
import GHCN_archive as GHCN

# %%
ghcn = GHCN.GHCN_archive()
# Out:
# Checking: static\src\ghcnd_all.tar.gz
# Checking: static\src\ghcnd-version.txt
# Checking: static\src\ghcnd-stations.txt
# Checking: static\src\ghcnd-inventory.txt
# Checking: static\src\ghcnd-countries.txt
# Checking: static\src\ghcnd-states.txt
# Version found: 3.27-upd-2019081018

# %%
ghcn.list_files()
# Out:
# ghcnd-countries.txt
# ghcnd-inventory.txt
# ghcnd-states.txt
# ghcnd-stations.txt
# ghcnd-version.txt
# ghcnd_all
# ghcnd_all.tar.gz
# US1MNAA0002.dly
# USW00014925.dly
# USW00014992.dly
# USW00094960.dly

# %%
ghcn.files
# Out:
# {'GHCN_TGZ': 'ghcnd_all.tar.gz',
#  'GHCN_VERSION': 'ghcnd-version.txt',
#  'GHCN_STATIONS': 'ghcnd-stations.txt',
#  'GHCN_INVENTORY': 'ghcnd-inventory.txt',
#  'GHCN_COUNTRIES': 'ghcnd-countries.txt',
#  'GHCN_STATES': 'ghcnd-states.txt',
#  'GHCN_DAILY': 'static\\src\\ghcnd_all'}

# %%
ghcn.path
# Out:
# 'static\\src'

# %%
# How to access the files of our archive
print(os.path.join(ghcn.path, ghcn.files['GHCN_INVENTORY']))
# Out:
# static\src\ghcnd-inventory.txt

# %%
# Create the database directory
DATABASE_DIRECTORY = os.path.join("static", "data")
DATABASE_FILE = "ghcn.db"
if not os.path.exists(DATABASE_DIRECTORY):
    os.makedirs(DATABASE_DIRECTORY)
    
DATABASE_PATH = os.path.join(DATABASE_DIRECTORY, DATABASE_FILE)

# %%
# Create a connection to a SQLite database
engine = create_engine(f'sqlite:///{DATABASE_PATH}')

# %%
print(engine)
# Out:
# Engine(sqlite:///static\data\ghcn.db)

# %% [markdown]
# # Declare the classes

# %%
class Countries(Base):
    __tablename__ = 'countries'
    fips = Column(String, primary_key=True)
    name = Column(String)
    
class States(Base):
    __tablename__ = 'states'
    fips = Column(String, primary_key=True)
    name = Column(String)

class Stations(Base):
    __tablename__ = 'stations'
    station_id = Column(String, primary_key=True)
    latitude = Column(Float)
    longitude = Column(Float)
    elevation = Column(Float)
    country_id = Column(String, ForeignKey('countries.fips'))
    state_id = Column(String, ForeignKey('states.fips'))
    name = Column(String)
    gsn = Column(String)
    hcn = Column(String)
    wmo = Column(Integer)
    
    country = relationship('Countries', foreign_keys=[country_id])
    state = relationship('States', foreign_keys=[state_id])

# Create the Inventory class
class Inventory(Base):
    __tablename__ = 'inventory'
    id = Column(Integer, primary_key=True)
    station_id = Column(String(12), ForeignKey('stations.station_id'))
    element = Column(String(6))
    first_year = Column(Integer)
    last_year = Column(Integer)
    
    station = relationship('Stations', foreign_keys=[station_id])

# %%
# Create the four tables within the database
Base.metadata.create_all(engine)

# %% [markdown]
# # First fill the Countries table

# %% [raw]
# V. FORMAT OF "ghcnd-countries.txt"
#
# ------------------------------
# Variable   Columns   Type
# ------------------------------
# CODE          1-2    Character
# NAME         4-50    Character
# ------------------------------

# %%
countries_file = os.path.join(ghcn.path, ghcn.files['GHCN_COUNTRIES'])
countries_colspecs = [(0, 3), (3, 50)]
countries_colnames = ['fips', 'name']

countries_df = pd.read_fwf(countries_file, colspecs=countries_colspecs,
                          names=countries_colnames)
countries_df.head()
# Out:
#   fips                  name
# 0   AC   Antigua and Barbuda
# 1   AE  United Arab Emirates
# 2   AF           Afghanistan
# 3   AG               Algeria
# 4   AJ            Azerbaijan

# %%
# To push the objects made and query the server we use a Session object
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
# Iterate over the rows and add to the table
for row in countries_df.itertuples():
    country = Countries(fips=row.fips, name=row.name)
    session.add(country)
    session.commit()

# %%
items = session.query(Countries)
for item in items:
    print(f"fips: {item.fips}, name: {item.name}")
# Out:
# fips: AC, name: Antigua and Barbuda
# fips: AE, name: United Arab Emirates
# fips: AF, name: Afghanistan
# fips: AG, name: Algeria
# fips: AJ, name: Azerbaijan
# fips: AL, name: Albania
# fips: AM, name: Armenia
# fips: AO, name: Angola
# fips: AQ, name: American Samoa [United States]
# fips: AR, name: Argentina
# fips: AS, name: Australia
# fips: AU, name: Austria
# fips: AY, name: Antarctica
# fips: BA, name: Bahrain
# fips: BB, name: Barbados
# fips: BC, name: Botswana
# fips: BD, name: Bermuda [United Kingdom]
# fips: BE, name: Belgium
# fips: BF, name: Bahamas, The
# fips: BG, name: Bangladesh
# fips: BH, name: Belize
# fips: BK, name: Bosnia and Herzegovina
# fips: BL, name: Bolivia
# fips: BM, name: Burma
# fips: BN, name: Benin
# fips: BO, name: Belarus
# fips: BP, name: Solomon Islands
# fips: BR, name: Brazil
# fips: BU, name: Bulgaria
# fips: BX, name: Brunei
# fips: BY, name: Burundi
# fips: CA, name: Canada
# fips: CB, name: Cambodia
# fips: CD, name: Chad
# fips: CE, name: Sri Lanka
# fips: CF, name: Congo (Brazzaville)
# fips: CG, name: Congo (Kinshasa)
# fips: CH, name: China
# fips: CI, name: Chile
# fips: CJ, name: Cayman Islands [United Kingdom]
# fips: CK, name: Cocos (Keeling) Islands [Australia]
# fips: CM, name: Cameroon
# fips: CO, name: Colombia
# fips: CQ, name: Northern Mariana Islands [United States]
# fips: CS, name: Costa Rica
# fips: CT, name: Central African Republic
# fips: CU, name: Cuba
# fips: CV, name: Cape Verde
# fips: CW, name: Cook Islands [New Zealand]
# fips: CY, name: Cyprus
# fips: DA, name: Denmark
# fips: DO, name: Dominica
# fips: DR, name: Dominican Republic
# fips: EC, name: Ecuador
# fips: EG, name: Egypt
# fips: EI, name: Ireland
# fips: EK, name: Equatorial Guinea
# fips: EN, name: Estonia
# fips: ER, name: Eritrea
# fips: ES, name: El Salvador
# fips: ET, name: Ethiopia
# fips: EU, name: Europa Island [France]
# fips: EZ, name: Czech Republic
# fips: FG, name: French Guiana [France]
# fips: FI, name: Finland
# fips: FJ, name: Fiji
# fips: FK, name: Falkland Islands (Islas Malvinas) [United Kingd
# fips: FM, name: Federated States of Micronesia
# fips: FP, name: French Polynesia
# fips: FR, name: France
# fips: FS, name: French Southern and Antarctic Lands [France]
# fips: GA, name: Gambia, The
# fips: GB, name: Gabon
# fips: GG, name: Georgia
# fips: GH, name: Ghana
# fips: GI, name: Gibraltar [United Kingdom]
# fips: GL, name: Greenland [Denmark]
# fips: GM, name: Germany
# fips: GP, name: Guadeloupe [France]
# fips: GQ, name: Guam [United States]
# fips: GR, name: Greece
# fips: GT, name: Guatemala
# fips: GV, name: Guinea
# fips: GY, name: Guyana
# fips: HO, name: Honduras
# fips: HR, name: Croatia
# fips: HU, name: Hungary
# fips: IC, name: Iceland
# fips: ID, name: Indonesia
# fips: IN, name: India
# fips: IO, name: British Indian Ocean Territory [United Kingdom]
# fips: IR, name: Iran
# fips: IS, name: Israel
# fips: IT, name: Italy
# fips: IV, name: Cote D'Ivoire
# fips: IZ, name: Iraq
# fips: JA, name: Japan
# fips: JM, name: Jamaica
# fips: JN, name: Jan Mayen [Norway]
# fips: JO, name: Jordan
# fips: JQ, name: Johnston Atoll [United States]
# fips: JU, name: Juan De Nova Island [France]
# fips: KE, name: Kenya
# fips: KG, name: Kyrgyzstan
# fips: KN, name: Korea, North
# fips: KR, name: Kiribati
# fips: KS, name: Korea, South
# fips: KT, name: Christmas Island [Australia]
# fips: KU, name: Kuwait
# fips: KZ, name: Kazakhstan
# fips: LA, name: Laos
# fips: LE, name: Lebanon
# fips: LG, name: Latvia
# fips: LH, name: Lithuania
# fips: LI, name: Liberia
# fips: LO, name: Slovakia
# fips: LQ, name: Palmyra Atoll [United States]
# fips: LT, name: Lesotho
# fips: LU, name: Luxembourg
# fips: LY, name: Libya
# fips: MA, name: Madagascar
# fips: MB, name: Martinique [France]
# fips: MC, name: Macau S.A.R
# fips: MD, name: Moldova
# fips: MF, name: Mayotte [France]
# fips: MG, name: Mongolia
# fips: MI, name: Malawi
# fips: MJ, name: Montenegro
# fips: MK, name: Macedonia
# fips: ML, name: Mali
# fips: MO, name: Morocco
# fips: MP, name: Mauritius
# fips: MQ, name: Midway Islands [United States}
# fips: MR, name: Mauritania
# fips: MT, name: Malta
# fips: MU, name: Oman
# fips: MV, name: Maldives
# fips: MX, name: Mexico
# fips: MY, name: Malaysia
# fips: MZ, name: Mozambique
# fips: NC, name: New Caledonia [France]
# fips: NE, name: Niue [New Zealand]
# fips: NF, name: Norfolk Island [Australia]
# fips: NG, name: Niger
# fips: NH, name: Vanuatu
# fips: NI, name: Nigeria
# fips: NL, name: Netherlands
# fips: NN, name: Sint Maarten
# fips: NO, name: Norway
# fips: NP, name: Nepal
# fips: NS, name: Suriname
# fips: NU, name: Nicaragua
# fips: NZ, name: New Zealand
# fips: PA, name: Paraguay
# fips: PC, name: Pitcairn Islands [United Kingdom]
# fips: PE, name: Peru
# fips: PK, name: Pakistan
# fips: PL, name: Poland
# fips: PM, name: Panama
# fips: PO, name: Portugal
# fips: PP, name: Papua New Guinea
# fips: PS, name: Palau
# fips: PU, name: Guinea-Bissau
# fips: QA, name: Qatar
# fips: RE, name: Reunion [France]
# fips: RI, name: Serbia
# fips: RM, name: Marshall Islands
# fips: RO, name: Romania
# fips: RP, name: Philippines
# fips: RQ, name: Puerto Rico [United States]
# fips: RS, name: Russia
# fips: RW, name: Rwanda
# fips: SA, name: Saudi Arabia
# fips: SB, name: Saint Pierre and Miquelon [France]
# fips: SE, name: Seychelles
# fips: SF, name: South Africa
# fips: SG, name: Senegal
# fips: SH, name: Saint Helena [United Kingdom]
# fips: SI, name: Slovenia
# fips: SL, name: Sierra Leone
# fips: SN, name: Singapore
# fips: SP, name: Spain
# fips: ST, name: Saint Lucia
# fips: SU, name: Sudan
# fips: SV, name: Svalbard [Norway]
# fips: SW, name: Sweden
# fips: SX, name: South Georgia and the South Sandwich Islands [U
# fips: SY, name: Syria
# fips: SZ, name: Switzerland
# fips: TD, name: Trinidad and Tobago
# fips: TE, name: Tromelin Island [France]
# fips: TH, name: Thailand
# fips: TI, name: Tajikistan
# fips: TL, name: Tokelau [New Zealand]
# fips: TN, name: Tonga
# fips: TO, name: Togo
# fips: TS, name: Tunisia
# fips: TU, name: Turkey
# fips: TV, name: Tuvalu
# fips: TX, name: Turkmenistan
# fips: TZ, name: Tanzania
# fips: UC, name: Curacao
# fips: UG, name: Uganda
# fips: UK, name: United Kingdom
# fips: UP, name: Ukraine
# fips: US, name: United States
# fips: UV, name: Burkina Faso
# fips: UY, name: Uruguay
# fips: UZ, name: Uzbekistan
# fips: VE, name: Venezuela
# fips: VM, name: Vietnam
# fips: VQ, name: Virgin Islands [United States]
# fips: WA, name: Namibia
# fips: WF, name: Wallis and Futuna [France]
# fips: WI, name: Western Sahara
# fips: WQ, name: Wake Island [United States]
# fips: WZ, name: Swaziland
# fips: ZA, name: Zambia
# fips: ZI, name: Zimbabwe

# %% [markdown]
# # Fill the States Table

# %% [raw]
# VI. FORMAT OF "ghcnd-states.txt"
#
# ------------------------------
# Variable   Columns   Type
# ------------------------------
# CODE          1-2    Character
# NAME         4-50    Character
# ------------------------------

# %%
states_file = os.path.join(ghcn.path, ghcn.files['GHCN_STATES'])
states_colspecs = [(0, 3), (3, 50)]
states_colnames = ['fips', 'name']

states_df = pd.read_fwf(states_file, colspecs=states_colspecs,
                          names=states_colnames)
states_df.head()
# Out:
#   fips            name
# 0   AB         ALBERTA
# 1   AK          ALASKA
# 2   AL         ALABAMA
# 3   AR        ARKANSAS
# 4   AS  AMERICAN SAMOA

# %%
# Iterate over the rows and add to the table
for row in states_df.itertuples():
    state = States(fips=row.fips, name=row.name)
    session.add(state)
    session.commit()

# %%
items = session.query(States)
for item in items:
    print(f"fips: {item.fips}, name: {item.name}")
# Out:
# fips: AB, name: ALBERTA
# fips: AK, name: ALASKA
# fips: AL, name: ALABAMA
# fips: AR, name: ARKANSAS
# fips: AS, name: AMERICAN SAMOA
# fips: AZ, name: ARIZONA
# fips: BC, name: BRITISH COLUMBIA
# fips: CA, name: CALIFORNIA
# fips: CO, name: COLORADO
# fips: CT, name: CONNECTICUT
# fips: DC, name: DISTRICT OF COLUMBIA
# fips: DE, name: DELAWARE
# fips: FL, name: FLORIDA
# fips: FM, name: MICRONESIA
# fips: GA, name: GEORGIA
# fips: GU, name: GUAM
# fips: HI, name: HAWAII
# fips: IA, name: IOWA
# fips: ID, name: IDAHO
# fips: IL, name: ILLINOIS
# fips: IN, name: INDIANA
# fips: KS, name: KANSAS
# fips: KY, name: KENTUCKY
# fips: LA, name: LOUISIANA
# fips: MA, name: MASSACHUSETTS
# fips: MB, name: MANITOBA
# fips: MD, name: MARYLAND
# fips: ME, name: MAINE
# fips: MH, name: MARSHALL ISLANDS
# fips: MI, name: MICHIGAN
# fips: MN, name: MINNESOTA
# fips: MO, name: MISSOURI
# fips: MP, name: NORTHERN MARIANA ISLANDS
# fips: MS, name: MISSISSIPPI
# fips: MT, name: MONTANA
# fips: NB, name: NEW BRUNSWICK
# fips: NC, name: NORTH CAROLINA
# fips: ND, name: NORTH DAKOTA
# fips: NE, name: NEBRASKA
# fips: NH, name: NEW HAMPSHIRE
# fips: NJ, name: NEW JERSEY
# fips: NL, name: NEWFOUNDLAND AND LABRADOR
# fips: NM, name: NEW MEXICO
# fips: NS, name: NOVA SCOTIA
# fips: NT, name: NORTHWEST TERRITORIES
# fips: NU, name: NUNAVUT
# fips: NV, name: NEVADA
# fips: NY, name: NEW YORK
# fips: OH, name: OHIO
# fips: OK, name: OKLAHOMA
# fips: ON, name: ONTARIO
# fips: OR, name: OREGON
# fips: PA, name: PENNSYLVANIA
# fips: PE, name: PRINCE EDWARD ISLAND
# fips: PI, name: PACIFIC ISLANDS
# fips: PR, name: PUERTO RICO
# fips: PW, name: PALAU
# fips: QC, name: QUEBEC
# fips: RI, name: RHODE ISLAND
# fips: SC, name: SOUTH CAROLINA
# fips: SD, name: SOUTH DAKOTA
# fips: SK, name: SASKATCHEWAN
# fips: TN, name: TENNESSEE
# fips: TX, name: TEXAS
# fips: UM, name: U.S. MINOR OUTLYING ISLANDS
# fips: UT, name: UTAH
# fips: VA, name: VIRGINIA
# fips: VI, name: VIRGIN ISLANDS
# fips: VT, name: VERMONT
# fips: WA, name: WASHINGTON
# fips: WI, name: WISCONSIN
# fips: WV, name: WEST VIRGINIA
# fips: WY, name: WYOMING
# fips: YT, name: YUKON TERRITORY

# %% [markdown]
# # Fill the Stations Table

# %% [raw]
# IV. FORMAT OF "ghcnd-stations.txt"
#
# ------------------------------
# Variable   Columns   Type
# ------------------------------
# ID            1-11   Character
# LATITUDE     13-20   Real
# LONGITUDE    22-30   Real
# ELEVATION    32-37   Real
# STATE        39-40   Character
# NAME         42-71   Character
# GSN FLAG     73-75   Character
# HCN/CRN FLAG 77-79   Character
# WMO ID       81-85   Character
# ------------------------------

# %%
stations_file = os.path.join(ghcn.path, ghcn.files['GHCN_STATIONS'])
stations_colspecs = [(0,12),(12,21),(21,31),(31,38),(38,41),(41,72),(72,76),(76,80),(80,86)]
stations_colnames = ["station_id", "latitude", "longitude", "elevation", "state", "name", "gsn_flag", "hcn_crn_flag", "wmo_id"]

stations_df = pd.read_fwf(stations_file, colspecs=stations_colspecs,
                          names=stations_colnames)
stations_df.head()
# Out:
#     station_id  latitude  longitude  elevation state                   name  \
# 0  ACW00011604   17.1167   -61.7833       10.1   NaN  ST JOHNS COOLIDGE FLD
# 1  ACW00011647   17.1333   -61.7833       19.2   NaN               ST JOHNS
# 2  AE000041196   25.3330    55.5170       34.0   NaN    SHARJAH INTER. AIRP
# 3  AEM00041194   25.2550    55.3640       10.4   NaN             DUBAI INTL
# 4  AEM00041217   24.4330    54.6510       26.8   NaN         ABU DHABI INTL
#
#   gsn_flag hcn_crn_flag   wmo_id
# 0      NaN          NaN      NaN
# 1      NaN          NaN      NaN
# 2      GSN          NaN  41196.0
# 3      NaN          NaN  41194.0
# 4      NaN          NaN  41217.0

# %%
def country_id(station_id):
    return station_id[:2]

stations_df['country'] = stations_df['station_id'].map(country_id)
stations_df.head()
# Out:
#     station_id  latitude  longitude  elevation state                   name  \
# 0  ACW00011604   17.1167   -61.7833       10.1   NaN  ST JOHNS COOLIDGE FLD
# 1  ACW00011647   17.1333   -61.7833       19.2   NaN               ST JOHNS
# 2  AE000041196   25.3330    55.5170       34.0   NaN    SHARJAH INTER. AIRP
# 3  AEM00041194   25.2550    55.3640       10.4   NaN             DUBAI INTL
# 4  AEM00041217   24.4330    54.6510       26.8   NaN         ABU DHABI INTL
#
#   gsn_flag hcn_crn_flag   wmo_id country
# 0      NaN          NaN      NaN      AC
# 1      NaN          NaN      NaN      AC
# 2      GSN          NaN  41196.0      AE
# 3      NaN          NaN  41194.0      AE
# 4      NaN          NaN  41217.0      AE

# %%
# Iterate over the rows and add to the table
for row in stations_df.itertuples():
    station = Stations(station_id = row.station_id,
                       latitude = row.latitude,
                       longitude = row.longitude,
                       elevation = row.elevation,
                       country_id = row.country,
                       state_id = row.state,
                       name = row.name,
                       gsn = row.gsn_flag,
                       hcn = row.hcn_crn_flag,
                       wmo = row.wmo_id)
    session.add(station)
    session.commit()

# %%
items = session.query(Stations.station_id, Stations.latitude, Stations.longitude, Stations.name).limit(5).all()
for item in items:
    print(item)
# Out:
# ('ACW00011604', 17.1167, -61.7833, 'ST JOHNS COOLIDGE FLD')
# ('ACW00011647', 17.1333, -61.7833, 'ST JOHNS')
# ('AE000041196', 25.333, 55.517, 'SHARJAH INTER. AIRP')
# ('AEM00041194', 25.255, 55.364, 'DUBAI INTL')
# ('AEM00041217', 24.433, 54.651, 'ABU DHABI INTL')

# %%
items = session.query(Stations.station_id, Stations.latitude, Stations.longitude, Stations.name).filter(Stations.state_id == 'MN').all()
print(f"The number of stations in Minnesota: {len(items)}")
for item in items:
    print(item)
# Out:
# The number of stations in Minnesota: 1251
# ('US1MNAA0002', 45.1947, -93.3257, 'COON RAPIDS 1.5 NNW')
# ('US1MNAA0003', 45.1962, -93.2755, 'COON RAPIDS 2.2 NE')
# ('US1MNAA0004', 45.409, -93.309, 'SAINT FRANCIS 4.0 E')
# ('US1MNAA0005', 45.3846, -93.1553, 'EAST BETHEL 3.1 NE')
# ('US1MNAA0006', 45.1708, -93.257, 'BLAINE 2.4 W')
# ('US1MNAA0012', 45.2451, -93.2068, 'HAM LAKE 0.7 SSW')
# ('US1MNAA0013', 45.1648, -93.2855, 'COON RAPIDS 1.4 ESE')
# ('US1MNAA0014', 45.2183, -93.2973, 'ANDOVER 3.0 SSE')
# ('US1MNAA0015', 45.1426, -93.1195, 'LINO LAKES 2.5 SW')
# ('US1MNAA0016', 45.3712, -93.2115, 'EAST BETHEL 1.1 NNW')
# ('US1MNAA0017', 45.0598, -93.2408, 'COLUMBIA HEIGHTS 0.9 NNE')
# ('US1MNAA0018', 45.2854, -93.3438, 'ANDOVER 2.1 NNW')
# ('US1MNAA0019', 45.189, -93.3719, 'COON RAPIDS 3.2 WNW')
# ('US1MNAA0020', 45.1646, -93.2072, 'BLAINE 0.4 S')
# ('US1MNAA0021', 45.2657, -93.2221, 'HAM LAKE 1.2 NW')
# ('US1MNAA0022', 45.3934, -93.365, 'SAINT FRANCIS 1.3 ESE')
# ('US1MNAA0023', 45.0847, -93.2648, 'FRIDLEY 0.3 W')
# ('US1MNAA0024', 45.2415, -93.4604, 'RAMSEY 1.5 SSW')
# ('US1MNAA0028', 45.176, -93.2226, 'BLAINE 0.8 WNW')
# ('US1MNAA0029', 45.2158, -93.1691, 'HAM LAKE 3.2 SSE')
# ('US1MNAA0031', 45.2488, -93.1597, 'HAM LAKE 2.2 E')
# ('US1MNAA0036', 45.2582, -93.4114, 'RAMSEY 1.9 E')
# ('US1MNAA0039', 45.0728, -93.2324, 'FRIDLEY 1.8 ESE')
# ('US1MNAA0040', 45.2387, -93.1892, 'HAM LAKE 1.3 SSE')
# ('US1MNAA0045', 45.1832, -93.2766, 'COON RAPIDS 1.7 ENE')
# ('US1MNAA0052', 45.1912, -93.2084, 'BLAINE 1.5 N')
# ('US1MNAA0054', 45.1947, -93.3749, 'ANOKA 1.3 SSE')
# ('US1MNAA0056', 45.1984, -93.2281, 'BLAINE 2.2 NNW')
# ('US1MNAA0057', 45.4006, -93.4002, 'SAINT FRANCIS 0.5 WNW')
# ('US1MNAA0061', 45.1876, -93.3391, 'COON RAPIDS 1.7 WNW')
# ('US1MNAA0067', 45.148, -93.1222, 'LINO LAKES 2.4 SW')
# ('US1MNAA0068', 45.3867, -93.1599, 'EAST BETHEL 3.0 NE')
# ('US1MNAA0073', 45.3023, -93.4146, 'ANOKA 6.5 N')
# ('US1MNAA0075', 45.1704, -93.0436, 'CENTERVILLE 0.7 NE')
# ('US1MNAA0076', 45.3036, -93.4262, 'NOWTHEN 2.9 SSE')
# ('US1MNAT0001', 46.2052, -93.2494, 'MCGRATH 2.8 SSE')
# ('US1MNAT0002', 46.995, -93.5971, 'HILL CITY 0.9 N')
# ('US1MNAT0004', 46.7138, -93.2885, 'MCGREGOR 7.3 N')
# ('US1MNAT0005', 46.6376, -93.1455, 'TAMARACK 1.4 SW')
# ('US1MNBK0002', 46.8298, -96.1605, 'LAKE PARK 4.8 SW')
# ('US1MNBK0003', 46.9583, -95.6551, 'ROCHERT 7.0 NNE')
# ('US1MNBK0006', 46.7985, -96.1218, 'LAKE PARK 6.0 S')
# ('US1MNBK0010', 46.8867, -95.8444, 'DETROIT LAKES 5.7 N')
# ('US1MNBK0011', 46.7703, -96.0747, 'LAKE PARK 7.9 S')
# ('US1MNBM0003', 47.5417, -94.7207, 'BEMIDJI 8.3 ENE')
# ('US1MNBM0007', 47.8829, -94.5026, 'KELLIHER 5.0 SSW')
# ('US1MNBM0009', 47.489, -94.8157, 'BEMIDJI 2.9 E')
# ('US1MNBM0010', 47.4658, -94.9477, 'BEMIDJI 3.5 WSW')
# ('US1MNBM0011', 47.5494, -94.8567, 'BEMIDJI 4.8 NNE')
# ('US1MNBM0012', 47.5798, -94.6824, 'TURTLE RIVER 3.6 E')
# ('US1MNBM0014', 47.4907, -95.1218, 'SOLWAY 2.1 S')
# ('US1MNBM0015', 47.5204, -94.7212, 'BEMIDJI 7.8 ENE')
# ('US1MNBN0004', 45.6269, -94.1953, 'SARTELL 0.7 ENE')
# ('US1MNBN0005', 45.6667, -93.8868, 'FOLEY 1.1 ENE')
# ('US1MNBU0002', 43.975, -93.9586, 'MAPLETON 3.5 N')
# ('US1MNBU0003', 44.1731, -93.9766, 'MANKATO 0.2 NNE')
# ('US1MNBU0006', 44.1854, -94.1591, 'LAKE CRYSTAL 6.3 NNE')
# ('US1MNBU0008', 44.1502, -94.0212, 'MANKATO 2.6 WSW')
# ('US1MNBU0010', 44.1488, -94.017, 'MANKATO 2.4 SW')
# ('US1MNBU0011', 44.1536, -94.0312, 'MANKATO 2.9 WSW')
# ('US1MNBU0018', 44.119, -93.9299, 'MANKATO 4.3 SE')
# ('US1MNBU0023', 44.1571, -93.9538, 'MANKATO 1.5 SE')
# ('US1MNBU0026', 44.2148, -93.8067, 'MADISON LAKE 0.8 NNE')
# ('US1MNBW0001', 44.2612, -94.9922, 'SPRINGFIELD 1.7 NNW')
# ('US1MNBW0002', 44.3217, -94.4771, 'NEW ULM 0.8 NW')
# ('US1MNBW0006', 44.1112, -94.798, 'COMFREY 5.2 E')
# ('US1MNBW0007', 44.2402, -94.9803, 'SPRINGFIELD 0.2 NNE')
# ('US1MNBW0008', 44.1511, -94.7852, 'COMFREY 6.5 ENE')
# ('US1MNBW0011', 44.2914, -94.7373, 'SLEEPY EYE 0.8 SW')
# ('US1MNCD0001', 44.181, -95.3273, 'LAMBERTON 4.6 SW')
# ('US1MNCD0002', 44.0958, -94.9257, 'COMFREY 1.6 SW')
# ('US1MNCG0001', 45.7169, -92.9257, 'RUSH CITY 2.8 NE')
# ('US1MNCG0003', 45.3586, -92.8792, 'CHISAGO CITY 1.8 ENE')
# ('US1MNCG0005', 45.6817, -93.0409, 'RUSH CITY 3.6 W')
# ('US1MNCG0007', 45.395, -93.0181, 'STACY 1.4 NW')
# ('US1MNCG0008', 45.3224, -92.9734, 'WYOMING 1.0 S')
# ('US1MNCG0009', 45.3085, -92.8004, 'LINDSTROM 5.9 SSE')
# ('US1MNCG0010', 45.3203, -92.955, 'WYOMING 1.5 SE')
# ('US1MNCG0011', 45.3318, -92.8982, 'CHISAGO CITY 1.3 SSE')
# ('US1MNCG0016', 45.5312, -92.9711, 'NORTH BRANCH 1.3 NNW')
# ('US1MNCG0019', 45.6647, -93.0889, 'STANCHFIELD 4.5 E')
# ('US1MNCG0020', 45.3203, -92.955, 'WYOMING 1.5 SE')
# ('US1MNCG0021', 45.401, -92.981, 'STACY 1.4 NNE')
# ('US1MNCG0023', 45.2993, -92.8695, 'CHISAGO CITY 3.9 SSE')
# ('US1MNCG0025', 45.4884, -92.9661, 'NORTH BRANCH 1.8 S')
# ('US1MNCG0027', 45.5005, -93.0054, 'NORTH BRANCH 2.4 WSW')
# ('US1MNCG0028', 45.6363, -93.0906, 'STANCHFIELD 4.9 ESE')
# ('US1MNCG0029', 45.3882, -92.8272, 'CENTER CITY 0.8 WSW')
# ('US1MNCK0002', 47.8398, -89.9678, 'HOVLAND 0.4 SW')
# ('US1MNCK0003', 47.6239, -90.761, 'TOFTE 4.9 NE')
# ('US1MNCK0006', 47.7487, -90.4376, 'GRAND MARAIS 4.4 W')
# ('US1MNCK0007', 47.8392, -89.9712, 'HOVLAND 0.1 NE')
# ('US1MNCK0015', 47.8542, -90.0181, 'HOVLAND 2.4 WNW')
# ('US1MNCK0018', 47.7446, -90.438, 'GRAND MARAIS 4.4 WSW')
# ('US1MNCL0002', 47.2889, -95.3283, 'BAGLEY 16.6 SSE')
# ('US1MNCN0001', 46.7078, -92.3279, 'CARLTON 5.6 NE')
# ('US1MNCN0005', 46.668, -92.5901, 'CLOQUET 5.9 SW')
# ('US1MNCN0006', 46.5113, -92.7391, 'BARNUM 2.4 W')
# ('US1MNCN0012', 46.6029, -92.682, 'MAHTOWA 3.2 NW')
# ('US1MNCN0017', 46.6185, -92.3285, 'WRENSHALL 2.6 E')
# ('US1MNCN0018', 46.5879, -92.3823, 'WRENSHALL 2.3 S')
# ('US1MNCN0019', 46.7186, -92.3476, 'ESKO 1.1 NE')
# ('US1MNCN0023', 46.4852, -92.3403, 'WRENSHALL 9.7 SSE')
# ('US1MNCP0001', 44.9453, -95.7203, 'MONTEVIDEO 0.4 SSW')
# ('US1MNCP0002', 44.923, -95.3877, 'CLARA CITY 2.8 SSW')
# ('US1MNCP0005', 44.9816, -95.7189, 'MONTEVIDEO 2.2 N')
# ('US1MNCS0001', 46.4025, -94.4631, 'PILLAGER 5.1 N')
# ('US1MNCS0002', 47.0922, -93.9195, 'REMER 2.5 N')
# ('US1MNCS0003', 46.8041, -94.3931, 'BACKUS 5.8 ESE')
# ('US1MNCS0006', 46.4094, -94.3288, 'EAST GULL LAKE 1.6 NE')
# ('US1MNCS0008', 46.8887, -94.3213, 'LONGVILLE 8.5 SW')
# ('US1MNCS0011', 46.9152, -94.2947, 'LONGVILLE 6.2 SW')
# ('US1MNCS0014', 46.7516, -94.361, 'PINE RIVER 2.7 NE')
# ('US1MNCS0015', 46.6451, -94.4329, 'PINE RIVER 5.6 SSW')
# ('US1MNCS0016', 47.0329, -94.4469, 'WALKER 7.6 ESE')
# ('US1MNCS0018', 46.9558, -94.3727, 'HACKENSACK 7.0 ENE')
# ('US1MNCV0001', 44.7573, -93.6416, 'CARVER 0.7 W')
# ('US1MNCV0008', 44.9663, -93.8489, 'WATERTOWN 0.5 NNW')
# ('US1MNCV0011', 44.8513, -93.6569, 'VICTORIA 1.0 S')
# ('US1MNCV0012', 44.8536, -93.5863, 'CHANHASSEN 1.2 W')
# ('US1MNCV0014', 44.8467, -93.5456, 'CHANHASSEN 1.0 ESE')
# ('US1MNCV0017', 44.7762, -93.9065, 'NORWOOD YOUNG AMERICA 0.8 ENE')
# ('US1MNCV0022', 44.8567, -93.6864, 'VICTORIA 1.6 WSW')
# ('US1MNCV0025', 44.8147, -93.5752, 'CHASKA 1.7 E')
# ('US1MNCV0027', 44.8898, -93.6099, 'CHANHASSEN 3.4 NW')
# ('US1MNCV0028', 44.8148, -93.597, 'CHASKA 0.6 E')
# ('US1MNCW0003', 46.4238, -94.3033, 'BRAINERD 6.9 NW')
# ('US1MNCW0004', 46.6177, -94.1909, 'BREEZY POINT 1.6 ENE')
# ('US1MNCW0005', 46.4832, -93.8308, 'AITKIN 6.8 WSW')
# ('US1MNCW0008', 46.3856, -93.9572, 'BRAINERD 11.5 E')
# ('US1MNCW0013', 46.4269, -94.3063, 'BRAINERD 7.1 NW')
# ('US1MNCW0015', 46.7098, -94.188, 'PINE RIVER 10.0 E')
# ('US1MNCW0016', 46.5585, -94.1172, 'TROMMALD 6.1 NW')
# ('US1MNCW0017', 46.746, -93.9616, 'EMILY 1.0 SSE')
# ('US1MNCW0019', 46.3608, -94.2838, 'BAXTER 1.3 N')
# ('US1MNCW0022', 46.1809, -94.3651, 'FORT RIPLEY 0.8 N')
# ('US1MNCW0029', 46.25, -94.1458, 'BRAINERD 7.7 SSE')
# ('US1MNCY0001', 46.8877, -96.748, 'MOORHEAD 2.0 N')
# ('US1MNCY0003', 46.7635, -96.22, 'HAWLEY 9.1 SSE')
# ('US1MNCY0006', 46.8293, -96.7832, 'MOORHEAD 2.8 SW')
# ('US1MNCY0010', 46.9445, -96.7794, 'MOORHEAD 6.2 NNW')
# ('US1MNCY0011', 46.8836, -96.7134, 'DILWORTH 0.8 WNW')
# ('US1MNCY0012', 46.9046, -96.6314, 'GLYNDON 3.3 NW')
# ('US1MNCY0017', 46.977, -96.2618, 'HITTERDAL 0.2 WSW')
# ('US1MNCY0018', 46.6408, -96.2309, 'BARNESVILLE 8.8 E')
# ('US1MNDD0003', 44.0504, -92.7214, 'MANTORVILLE 1.9 ESE')
# ('US1MNDD0004', 43.9751, -92.7183, 'KASSON 4.3 SSE')
# ('US1MNDD0010', 44.0098, -92.9856, 'CLAREMONT 2.5 SSE')
# ('US1MNDD0011', 44.0365, -92.9493, 'CLAREMONT 2.5 ESE')
# ('US1MNDD0014', 43.8864, -92.8459, 'HAYFIELD 0.3 SSE')
# ('US1MNDK0001', 44.7148, -92.8387, 'HASTINGS 1.4 SSE')
# ('US1MNDK0002', 44.7674, -93.2919, 'BURNSVILLE 0.6 WNW')
# ('US1MNDK0007', 44.815, -93.1981, 'EAGAN 1.7 W')
# ('US1MNDK0008', 44.8554, -93.0634, 'INVER GROVE HEIGHTS 2.1 N')
# ('US1MNDK0011', 44.7608, -93.13, 'ROSEMOUNT 3.3 WNW')
# ('US1MNDK0012', 44.7836, -93.2012, 'EAGAN 2.9 SW')
# ('US1MNDK0014', 44.8344, -93.0358, 'INVER GROVE HEIGHTS 1.3 ENE')
# ('US1MNDK0015', 44.7914, -93.2304, 'BURNSVILLE 3.0 NE')
# ('US1MNDK0016', 44.7514, -93.1936, 'ROSEMOUNT 6.3 W')
# ('US1MNDK0017', 44.6481, -93.2677, 'LAKEVILLE 2.2 SSW')
# ('US1MNDK0020', 44.6443, -93.2655, 'LAKEVILLE 2.4 SSW')
# ('US1MNDK0021', 44.8819, -93.0352, 'SOUTH SAINT PAUL 0.5 SE')
# ('US1MNDK0022', 44.6365, -93.1577, 'FARMINGTON 1.5 SSE')
# ('US1MNDK0023', 44.7182, -93.121, 'ROSEMOUNT 3.3 SW')
# ('US1MNDK0024', 44.7129, -92.8573, 'HASTINGS 1.3 S')
# ('US1MNDK0025', 44.7788, -93.1453, 'EAGAN 2.8 SSE')
# ('US1MNDK0026', 44.6965, -93.2577, 'LAKEVILLE 1.3 NNW')
# ('US1MNDK0027', 44.8026, -93.0819, 'INVER GROVE HEIGHTS 1.9 SW')
# ('US1MNDK0029', 44.6372, -93.2166, 'LAKEVILLE 3.3 SSE')
# ('US1MNDK0031', 44.6911, -93.2938, 'LAKEVILLE 2.3 WNW')
# ('US1MNDK0032', 44.4722, -93.1702, 'NORTHFIELD 1.1 NNW (126)')
# ('US1MNDK0033', 44.8062, -93.1771, 'EAGAN 1.0 SW')
# ('US1MNDK0034', 44.6407, -93.1432, 'FARMINGTON 1.7 SE')
# ('US1MNDK0035', 44.7124, -92.8618, 'HASTINGS 1.4 SSW')
# ('US1MNDK0036', 44.7248, -93.2445, 'APPLE VALLEY 2.6 SW')
# ('US1MNDK0039', 44.7418, -93.1821, 'APPLE VALLEY 1.0 ESE')
# ('US1MNDK0041', 44.8764, -93.1236, 'MENDOTA HEIGHTS 0.9 ESE')
# ('US1MNDK0043', 44.7626, -93.1803, 'APPLE VALLEY 1.5 NE')
# ('US1MNDK0044', 44.7208, -93.1497, 'ROSEMOUNT 4.5 WSW')
# ('US1MNDK0046', 44.741, -92.8698, 'HASTINGS 1.0 NW')
# ('US1MNDK0047', 44.843, -93.0314, 'INVER GROVE HEIGHTS 1.9 NE')
# ('US1MNDK0049', 44.6569, -93.2839, 'LAKEVILLE 2.1 SW')
# ('US1MNDK0051', 44.7579, -93.2567, 'BURNSVILLE 1.2 ESE')
# ('US1MNDK0053', 44.7042, -93.1846, 'LAKEVILLE 3.8 ENE')
# ('US1MNDK0054', 44.6301, -93.1483, 'FARMINGTON 2.1 SSE')
# ('US1MNDK0055', 44.9009, -93.0997, 'WEST SAINT PAUL 0.7 W')
# ('US1MNDK0056', 44.8025, -93.2093, 'EAGAN 2.4 WSW')
# ('US1MNDK0063', 44.4835, -93.1284, 'NORTHFIELD 2.4 NE')
# ('US1MNDK0067', 44.7504, -93.1502, 'ROSEMOUNT 4.1 W')
# ('US1MNDK0068', 44.6268, -93.1389, 'FARMINGTON 2.6 SE')
# ('US1MNDK0069', 44.73, -93.1373, 'ROSEMOUNT 3.7 WSW')
# ('US1MNDK0070', 44.8432, -93.179, 'EAGAN 2.0 NNW')
# ('US1MNDK0071', 44.7063, -93.2375, 'LAKEVILLE 2.1 NNE')
# ('US1MNDK0073', 44.7125, -93.2304, 'LAKEVILLE 2.6 NNE')
# ('US1MNDK0079', 44.8147, -93.0895, 'INVER GROVE HEIGHTS 1.6 WSW')
# ('US1MNDK0082', 44.7838, -93.0971, 'INVER GROVE HEIGHTS 3.4 SSW')
# ('US1MNDK0083', 44.7213, -93.2929, 'BURNSVILLE 3.1 SSW')
# ('US1MNDK0087', 44.804, -93.1273, 'EAGAN 2.0 ESE')
# ('US1MNDK0089', 44.5893, -92.8649, 'CANNON FALLS 5.6 NNE')
# ('US1MNDK0091', 44.7343, -92.8757, 'HASTINGS 1.1 W')
# ('US1MNDK0092', 44.8878, -93.1232, 'MENDOTA HEIGHTS 0.9 ENE')
# ('US1MNDK0095', 44.7506, -93.1326, 'ROSEMOUNT 3.3 W')
# ('US1MNDK0096', 44.6458, -93.0757, 'HAMPTON 4.4 NW')
# ('US1MNDK0104', 44.7446, -92.8804, 'HASTINGS 1.6 NW')
# ('US1MNDS0001', 45.9211, -95.3797, 'ALEXANDRIA 3.0 N')
# ('US1MNDS0003', 46.0487, -95.4333, 'MILTONA 6.7 W')
# ('US1MNDS0004', 45.8382, -95.4838, 'ALEXANDRIA 6.0 WSW')
# ('US1MNDS0005', 45.9677, -95.6025, 'BRANDON 0.4 WNW')
# ('US1MNDS0006', 45.8333, -95.6043, 'KENSINGTON 5.9 NE')
# ('US1MNDS0008', 45.8915, -95.3438, 'ALEXANDRIA 1.7 ENE')
# ('US1MNDS0009', 45.8783, -95.3827, 'ALEXANDRIA 0.5 W')
# ('US1MNDS0012', 45.8595, -95.3092, 'ALEXANDRIA 3.3 ESE')
# ('US1MNDS0015', 46.0031, -95.6027, 'EVANSVILLE 4.0 E')
# ('US1MNFM0001', 43.7879, -92.0266, 'CHATFIELD 9.0 ESE')
# ('US1MNFM0003', 43.6392, -92.4299, 'OSTRANDER 1.7 N')
# ('US1MNFM0004', 43.664, -92.0801, 'PRESTON 0.6 SSE')
# ('US1MNFM0005', 43.6886, -91.9037, 'WHALAN 3.3 SSE')
# ('US1MNFM0006', 43.613, -92.4251, 'OSTRANDER 0.2 ESE')
# ('US1MNFM0007', 43.713, -92.0518, 'PRESTON 3.2 NNE')
# ('US1MNFM0009', 43.8388, -92.1991, 'CHATFIELD 0.7 SW')
# ('US1MNFM0010', 43.7434, -92.3065, 'WYKOFF 3.1 NW')
# ('US1MNFN0001', 43.5535, -93.3176, 'GLENVILLE 2.3 SW')
# ('US1MNFN0002', 43.6547, -93.3625, 'ALBERT LEA 0.1 ENE')
# ('US1MNFN0003', 43.7596, -93.3303, 'CLARKS GROVE 0.3 SW')
# ('US1MNFN0004', 43.6354, -93.3618, 'ALBERT LEA 1.3 S')
# ('US1MNFN0005', 43.638, -93.385, 'ALBERT LEA 1.6 SW')
# ('US1MNFT0005', 43.637, -94.0891, 'BLUE EARTH 0.6 ESE')
# ('US1MNFT0006', 43.5212, -94.0867, 'ELMORE 1.0 N')
# ('US1MNGH0001', 44.5377, -92.5377, 'RED WING 4.4 SE')
# ('US1MNGH0002', 44.2767, -92.9913, 'KENYON 0.4 NW')
# ('US1MNGH0003', 44.456, -92.2907, 'LAKE CITY 1.2 NNW')
# ('US1MNGH0004', 44.3425, -92.9792, 'NERSTRAND 4.2 E')
# ('US1MNGH0007', 44.4955, -92.6111, 'RED WING 6.0 S')
# ('US1MNGH0008', 44.5333, -92.8746, 'CANNON FALLS 2.0 NE')
# ('US1MNGH0009', 44.3249, -92.6534, 'ZUMBROTA 2.3 NNE')
# ('US1MNGH0011', 44.2567, -92.781, 'WANAMINGO 3.2 S')
# ('US1MNGH0012', 44.2362, -92.7644, 'PINE ISLAND 6.4 WNW')
# ('US1MNGH0015', 44.4039, -93.0382, 'DENNISON 0.4 SSE')
# ('US1MNGH0016', 44.5495, -92.5555, 'RED WING 3.2 SE')
# ('US1MNGH0017', 44.3021, -92.6751, 'ZUMBROTA 0.5 N')
# ('US1MNGH0018', 44.4112, -92.8966, 'CANNON FALLS 7.1 S')
# ('US1MNGH0019', 44.4013, -92.6252, 'GOODHUE 0.0 NNE')
# ('US1MNGH0021', 44.577, -92.7046, 'WELCH 1.8 ENE')
# ('US1MNGH0022', 44.5635, -92.6244, 'RED WING 1.6 SW')
# ('US1MNGH0023', 44.5041, -92.9067, 'CANNON FALLS 0.7 SSW')
# ('US1MNGH0027', 44.4986, -92.315, 'LAKE CITY 4.4 NNW')
# ('US1MNGH0028', 44.5087, -92.8953, 'CANNON FALLS 0.5 SE')
# ('US1MNGH0029', 44.532, -92.6654, 'RED WING 4.6 SW')
# ('US1MNGR0002', 45.7773, -95.7626, 'KENSINGTON 3.2 W')
# ('US1MNGR0004', 45.7846, -95.7804, 'KENSINGTON 4.1 W')
# ('US1MNGR0007', 46.053, -95.9551, 'ELBOW LAKE 4.5 NNE')
# ('US1MNGR0008', 45.8636, -95.7971, 'HOFFMAN 2.2 NNW')
# ('US1MNGR0011', 45.8008, -95.8575, 'HOFFMAN 4.0 WSW')
# ('US1MNHB0003', 47.2379, -94.8104, 'LAPORTE 3.0 WNW')
# ('US1MNHN0003', 44.8717, -93.3055, 'RICHFIELD 1.2 WSW')
# ('US1MNHN0006', 44.9829, -93.5736, 'LONG LAKE 0.2 WSW')
# ('US1MNHN0008', 45.0269, -93.2346, 'SAINT ANTHONY 0.9 WNW')
# ('US1MNHN0009', 45.0039, -93.2895, 'MINNEAPOLIS 3.0 NNW')
# ('US1MNHN0014', 44.9145, -93.6992, 'MINNETRISTA 1.5 SSE')
# ('US1MNHN0015', 44.8483, -93.4564, 'EDEN PRAIRIE 0.2 ESE')
# ('US1MNHN0016', 44.8297, -93.5028, 'EDEN PRAIRIE 2.5 WSW')
# ('US1MNHN0017', 44.8294, -93.5201, 'EDEN PRAIRIE 3.3 WSW')
# ('US1MNHN0019', 44.8783, -93.3789, 'EDINA 1.3 SW')
# ('US1MNHN0020', 45.0364, -93.3642, 'CRYSTAL 0.2 WSW')
# ('US1MNHN0022', 44.9289, -93.3163, 'MINNEAPOLIS 3.3 SW')
# ('US1MNHN0025', 44.9817, -93.2783, 'MINNEAPOLIS TARGET FIELD')
# ('US1MNHN0028', 44.91, -93.289, 'MINNEAPOLIS 3.8 SSW')
# ('US1MNHN0030', 45.0406, -93.4195, 'PLYMOUTH 2.4 ENE')
# ('US1MNHN0031', 45.1226, -93.4579, 'MAPLE GROVE 1.0 NNE')
# ('US1MNHN0032', 44.9067, -93.3192, 'MINNEAPOLIS 4.6 SSW')
# ('US1MNHN0033', 45.2443, -93.5115, 'DAYTON 0.4 NE')
# ('US1MNHN0034', 45.0094, -93.3411, 'GOLDEN VALLEY 1.6 NNE')
# ('US1MNHN0035', 44.9408, -93.2169, 'MINNEAPOLIS 2.9 ESE')
# ('US1MNHN0036', 44.9284, -93.4755, 'MINNETONKA 0.7 WSW')
# ('US1MNHN0037', 45.0109, -93.4577, 'PLYMOUTH 0.8 SSE')
# ('US1MNHN0038', 44.9533, -93.3653, 'SAINT LOUIS PARK 0.3 N')
# ('US1MNHN0039', 45.093, -93.7359, 'ROCKFORD 0.5 NE')
# ('US1MNHN0040', 44.9225, -93.5368, 'DEEPHAVEN 0.8 SW')
# ('US1MNHN0041', 44.9228, -93.7198, 'MINNETRISTA 1.0 SSW')
# ('US1MNHN0042', 44.8451, -93.4171, 'EDEN PRAIRIE 2.1 E')
# ('US1MNHN0044', 44.9111, -93.2276, 'MINNEAPOLIS 4.1 SSE')
# ('US1MNHN0045', 44.8829, -93.2583, 'RICHFIELD 1.2 ENE')
# ('US1MNHN0047', 44.8665, -93.5004, 'EDEN PRAIRIE 2.3 WNW')
# ('US1MNHN0048', 45.0638, -93.4947, 'PLYMOUTH 3.3 NNW')
# ('US1MNHN0049', 45.1148, -93.414, 'MAPLE GROVE 2.4 E')
# ('US1MNHN0050', 45.0125, -93.4079, 'PLYMOUTH 2.7 ESE')
# ('US1MNHN0051', 45.087, -93.5243, 'CORCORAN 3.3 ESE')
# ('US1MNHN0052', 45.1593, -93.3576, 'CHAMPLIN 1.8 ESE')
# ('US1MNHN0053', 45.1984, -93.4813, 'DAYTON 3.4 SSE')
# ('US1MNHN0055', 45.0033, -93.3901, 'GOLDEN VALLEY 1.8 WNW')
# ('US1MNHN0057', 45.129, -93.4565, 'MAPLE GROVE 1.4 NNE')
# ('US1MNHN0058', 45.1585, -93.3653, 'CHAMPLIN 1.5 ESE (118)')
# ('US1MNHN0060', 45.0324, -93.4104, 'PLYMOUTH 2.6 ENE (152)')
# ('US1MNHN0061', 44.8457, -93.4549, 'EDEN PRAIRIE 0.3 SE')
# ('US1MNHN0062', 45.162, -93.414, 'CHAMPLIN 1.3 WSW')
# ('US1MNHN0064', 45.0195, -93.3379, 'CRYSTAL 1.7 SE')
# ('US1MNHN0065', 45.0083, -93.2363, 'MINNEAPOLIS 2.4 NE')
# ('US1MNHN0066', 44.8137, -93.3086, 'BLOOMINGTON 1.2 SSE')
# ('US1MNHN0072', 45.1395, -93.4207, 'MAPLE GROVE 2.9 NE')
# ('US1MNHN0074', 45.1931, -93.404, 'CHAMPLIN 1.7 NNW')
# ('US1MNHN0078', 44.8913, -93.3141, 'RICHFIELD 1.9 WNW')
# ('US1MNHN0081', 44.9112, -93.4164, 'HOPKINS 1.2 SSW')
# ('US1MNHN0082', 45.0586, -93.3778, 'CRYSTAL 1.7 NNW')
# ('US1MNHN0083', 44.9334, -93.6316, 'SPRING PARK 0.2 SSE')
# ('US1MNHN0084', 45.0349, -93.3127, 'MINNEAPOLIS 4.4 NNW')
# ('US1MNHN0085', 44.9131, -93.2219, 'MINNEAPOLIS 4.1 SSE')
# ('US1MNHN0086', 44.8283, -93.404, 'EDEN PRAIRIE 3.1 ESE')
# ('US1MNHN0088', 44.9846, -93.3744, 'GOLDEN VALLEY 0.8 WSW')
# ('US1MNHN0089', 44.9154, -93.3585, 'EDINA 1.7 N')
# ('US1MNHN0090', 44.9172, -93.2329, 'MINNEAPOLIS 3.6 SSE')
# ('US1MNHN0091', 44.9863, -93.4727, 'PLYMOUTH 2.6 SSW')
# ('US1MNHN0093', 44.9417, -93.2418, 'MINNEAPOLIS 1.9 SE')
# ('US1MNHN0099', 44.9247, -93.2494, 'MINNEAPOLIS 2.8 SSE')
# ('US1MNHN0103', 44.8927, -93.6166, 'SHOREWOOD 2.3 SW')
# ('US1MNHN0107', 44.9025, -93.2841, 'MINNEAPOLIS 4.2 S')
# ('US1MNHN0108', 45.0343, -93.2496, 'MINNEAPOLIS 3.6 NNE')
# ('US1MNHN0110', 44.8687, -93.3394, 'EDINA 1.9 SSE')
# ('US1MNHN0116', 44.9245, -93.5037, 'MINNETONKA 2.1 WSW')
# ('US1MNHN0120', 44.9427, -93.2079, 'MINNEAPOLIS 3.2 ESE')
# ('US1MNHN0125', 44.9043, -93.3179, 'MINNEAPOLIS 4.7 SSW')
# ('US1MNHN0128', 45.018, -93.3295, 'ROBBINSDALE 0.6 SSE')
# ('US1MNHN0134', 45.0674, -93.2934, 'BROOKLYN CENTER 1.1 E')
# ('US1MNHN0141', 44.9144, -93.2603, 'MINNEAPOLIS 3.3 S')
# ('US1MNHN0144', 45.0465, -93.3458, 'CRYSTAL 0.9 NE')
# ('US1MNHN0147', 44.9516, -93.3013, 'MINNEAPOLIS 1.8 WSW')
# ('US1MNHN0148', 45.0665, -93.5181, 'MAPLE GROVE 4.0 SW')
# ('US1MNHN0150', 45.125, -93.4344, 'MAPLE GROVE 1.8 NE')
# ('US1MNHN0151', 45.0403, -93.3185, 'MINNEAPOLIS 4.6 NNW')
# ('US1MNHN0152', 44.9502, -93.3549, 'SAINT LOUIS PARK 0.5 ENE')
# ('US1MNHN0154', 45.214, -93.4645, 'DAYTON 3.2 SE')
# ('US1MNHN0155', 44.9203, -93.2247, 'MINNEAPOLIS 3.6 SE')
# ('US1MNHN0156', 44.9153, -93.4886, 'MINNETONKA 1.8 SW')
# ('US1MNHN0157', 45.1286, -93.4158, 'MAPLE GROVE 2.7 ENE')
# ('US1MNHN0160', 44.9553, -93.2176, 'MINNEAPOLIS 2.5 ESE')
# ('US1MNHN0163', 44.944, -93.2432, 'MINNEAPOLIS 1.7 SE')
# ('US1MNHN0166', 44.8673, -93.3406, 'EDINA 1.9 SSE')
# ('US1MNHN0169', 44.951, -93.2175, 'MINNEAPOLIS 2.6 ESE')
# ('US1MNHN0171', 45.0907, -93.4692, 'MAPLE GROVE 1.3 SSW')
# ('US1MNHN0174', 44.9346, -93.2826, 'MINNEAPOLIS 2.1 SSW')
# ('US1MNHN0175', 44.8114, -93.2859, 'BLOOMINGTON 2.0 SE')
# ('US1MNHN0177', 44.9513, -93.3389, 'SAINT LOUIS PARK 1.3 E')
# ('US1MNHN0178', 44.9065, -93.2199, 'MINNEAPOLIS 4.5 SSE')
# ('US1MNHN0180', 44.8936, -93.2963, 'MINNEAPOLIS 5.0 SSW')
# ('US1MNHN0181', 44.9671, -93.2622, 'MINNEAPOLIS 0.4 NE')
# ('US1MNHN0184', 44.9946, -93.3724, 'GOLDEN VALLEY 0.7 WNW')
# ('US1MNHN0185', 45.0044, -93.5881, 'LONG LAKE 1.7 NNW')
# ('US1MNHN0186', 45.1037, -93.3058, 'BROOKLYN PARK 2.2 ESE')
# ('US1MNHN0191', 45.1544, -93.4187, 'CHAMPLIN 1.8 SW')
# ('US1MNHN0192', 44.9656, -93.427, 'MINNETONKA 2.8 NE')
# ('US1MNHN0198', 44.9052, -93.383, 'EDINA 1.5 NW')
# ('US1MNHN0200', 44.9463, -93.3652, 'SAINT LOUIS PARK 0.2 S')
# ('US1MNHN0201', 45.0241, -93.4248, 'PLYMOUTH 1.8 E')
# ('US1MNHN0203', 44.9317, -93.4164, 'HOPKINS 0.7 NW')
# ('US1MNHN0206', 45.1169, -93.5064, 'MAPLE GROVE 2.2 WNW')
# ('US1MNHN0211', 44.9605, -93.6315, 'ORONO 2.0 W')
# ('US1MNHN0212', 45.1301, -93.5159, 'MAPLE GROVE 3.0 WNW')
# ('US1MNHN0213', 44.973, -93.6225, 'ORONO 1.7 WNW')
# ('US1MNHN0214', 44.8973, -93.2454, 'MINNEAPOLIS 4.6 SSE')
# ('US1MNHN0215', 44.8775, -93.3107, 'RICHFIELD 1.4 W')
# ('US1MNHN0220', 44.8929, -93.7613, 'MINNETRISTA 3.9 SW')
# ('US1MNHN0221', 44.8099, -93.376, 'BLOOMINGTON 3.3 WSW')
# ('US1MNHN0222', 45.1196, -93.4441, 'MAPLE GROVE 1.2 NE')
# ('US1MNHS0003', 43.5152, -91.577, 'SPRING GROVE 4.4 SE')
# ('US1MNHS0004', 43.557, -91.513, 'CALEDONIA 5.4 S')
# ('US1MNHS0006', 43.7577, -91.4325, 'HOUSTON 6.9 E')
# ('US1MNHS0007', 43.8349, -91.3138, 'LA CRESCENT 0.7 WNW')
# ('US1MNHS0008', 43.8381, -91.3079, 'LA CRESCENT 0.7 NNW')
# ('US1MNHS0010', 43.6541, -91.2789, 'BROWNSVILLE 3.1 S')
# ('US1MNIS0001', 45.4991, -93.2542, 'ISANTI 0.7 NW')
# ('US1MNIS0002', 45.4154, -93.2336, 'ISANTI 5.4 S')
# ('US1MNIS0005', 45.4363, -93.2099, 'ISANTI 4.3 SSE (141)')
# ('US1MNIS0006', 45.605, -93.2345, 'CAMBRIDGE 3.0 N')
# ('US1MNIS0007', 45.4283, -93.2313, 'BETHEL 2.6 NE')
# ('US1MNIS0008', 45.7238, -93.1582, 'BRAHAM 0.7 ENE')
# ('US1MNIS0014', 45.5823, -93.2535, 'CAMBRIDGE 1.9 NW')
# ('US1MNIT0001', 47.2227, -93.496, 'GRAND RAPIDS 2.0 E')
# ('US1MNIT0005', 47.16, -93.64, 'COHASSET 5.1 S')
# ('US1MNIT0006', 47.3981, -93.0813, 'KEEWATIN 0.2 SSE')
# ('US1MNIT0007', 47.1369, -93.5666, 'GRAND RAPIDS 6.2 SSW')
# ('US1MNIT0010', 47.3356, -93.8751, 'DEER RIVER 3.7 W')
# ('US1MNIT0011', 47.545, -93.1942, 'NASHWAUK 11.5 N')
# ('US1MNIT0017', 47.3116, -93.5504, 'GRAND RAPIDS 6.1 N')
# ('US1MNIT0019', 47.342, -93.6976, 'COHASSET 7.6 NNW')
# ('US1MNIT0020', 47.2769, -93.4233, 'COLERAINE 1.5 S')
# ('US1MNJC0002', 43.8322, -95.3131, 'HERON LAKE 2.4 N')
# ('US1MNKB0001', 45.996, -93.3335, 'MORA 8.5 NNW')
# ('US1MNKB0002', 45.9064, -93.2979, 'MORA 2.1 N')
# ('US1MNKB0003', 45.9807, -93.2541, 'BROOK PARK 9.0 WNW')
# ('US1MNKB0005', 45.9234, -93.4753, 'OGILVIE 7.0 NNW')
# ('US1MNKB0007', 45.7873, -93.4939, 'OGILVIE 4.5 SW')
# ('US1MNKB0010', 45.8072, -93.3279, 'OGILVIE 4.8 ESE')
# ('US1MNKB0012', 45.7599, -93.4122, 'OGILVIE 4.8 S')
# ('US1MNKC0001', 48.597, -93.4256, 'INTERNATIONAL FALLS 1.0 NW')
# ('US1MNKC0003', 48.6068, -93.1854, 'INTERNATIONAL FALLS 10.2 E')
# ('US1MNKC0004', 48.4778, -93.4228, 'INTERNATIONAL FALLS 7.7 S')
# ('US1MNKD0001', 45.407, -94.8466, 'BELGRADE 8.0 ESE')
# ('US1MNKD0003', 45.1994, -95.0057, 'WILLMAR 5.9 NNE')
# ('US1MNKD0004', 45.2421, -95.1526, 'PENNOCK 6.7 N')
# ('US1MNKD0005', 45.2678, -95.0566, 'SPICER 6.1 WNW')
# ('US1MNKD0007', 45.115, -95.0319, 'WILLMAR 1.4 ESE')
# ('US1MNKD0008', 45.1178, -95.0559, 'WILLMAR 0.3 SSE')
# ('US1MNKD0010', 45.1187, -95.0551, 'WILLMAR 0.3 SSE')
# ('US1MNKD0013', 45.2648, -95.0631, 'SPICER 6.3 WNW')
# ('US1MNKT0002', 48.575, -96.5182, 'KARLSTAD 0.2 SSW')
# ('US1MNLK0001', 47.0185, -91.6627, 'TWO HARBORS 1.0 SE')
# ('US1MNLK0002', 47.088, -91.6241, 'TWO HARBORS 4.7 NNE')
# ('US1MNLK0003', 47.3145, -91.2301, 'SILVER BAY 2.7 ENE')
# ('US1MNLK0004', 47.0412, -91.7528, 'TWO HARBORS 3.6 WNW')
# ('US1MNLK0005', 47.1656, -91.6195, 'TWO HARBORS 9.7 NNE')
# ('US1MNLK0007', 47.0653, -91.6761, 'TWO HARBORS 2.4 N')
# ('US1MNLK0008', 47.2873, -91.2852, 'SILVER BAY 0.5 SW')
# ('US1MNLK0009', 47.4126, -91.1058, 'SILVER BAY 11.5 NE')
# ('US1MNLK0015', 47.382, -91.1494, 'SILVER BAY 8.6 NE')
# ('US1MNLN0002', 44.4595, -96.1373, 'IVANHOE 5.7 E')
# ('US1MNLQ0004', 44.8483, -96.0271, 'DAWSON 5.7 SSE')
# ('US1MNLS0001', 44.449, -93.5264, 'MONTGOMERY 2.6 E')
# ('US1MNLS0003', 44.5331, -93.5558, 'NEW PRAGUE 1.3 SE')
# ('US1MNLS0004', 44.4527, -93.8957, 'LE SUEUR 1.2 SSE (104)')
# ('US1MNLS0006', 44.2635, -93.8596, 'MADISON LAKE 4.6 NNW')
# ('US1MNLS0010', 44.2051, -93.678, 'ELYSIAN 0.7 N')
# ('US1MNLS0012', 44.4655, -93.7734, 'LE CENTER 5.8 NNW')
# ('US1MNLS0013', 44.5328, -93.5725, 'NEW PRAGUE 1.0 S')
# ('US1MNLS0015', 44.5403, -93.8859, 'HENDERSON 1.4 NE')
# ('US1MNLY0002', 44.4401, -95.7898, 'MARSHALL 0.6 S')
# ('US1MNLY0003', 44.524, -95.8395, 'GHENT 2.8 ENE')
# ('US1MNLY0004', 44.562, -95.9895, 'MINNEOTA 0.3 W')
# ('US1MNMC0003', 44.898, -94.3723, 'HUTCHINSON 0.9 NNE')
# ('US1MNMC0005', 44.7683, -94.1558, 'GLENCOE 0.3 WSW')
# ('US1MNMC0006', 44.8121, -94.179, 'GLENCOE 3.2 NNW')
# ('US1MNMC0007', 44.9279, -94.2041, 'SILVER LAKE 1.7 N')
# ('US1MNMC0009', 44.7384, -94.2044, 'GLENCOE 3.4 SW')
# ('US1MNMC0010', 44.8668, -94.3619, 'HUTCHINSON 1.5 SSE')
# ('US1MNMC0012', 44.966, -94.3645, 'HUTCHINSON 5.6 N')
# ('US1MNMC0013', 44.9037, -94.3906, 'HUTCHINSON 1.4 NNW')
# ('US1MNMC0016', 44.8863, -94.375, 'HUTCHINSON 0.1 ENE')
# ('US1MNMC0017', 44.7737, -94.0342, 'PLATO 0.3 ENE')
# ('US1MNMK0002', 45.1437, -94.2888, 'DASSEL 4.4 NNE')
# ('US1MNMK0003', 45.1519, -94.3019, 'DASSEL 4.8 N')
# ('US1MNMK0007', 44.9324, -94.6955, 'COSMOS 0.2 S')
# ('US1MNMK0008', 45.0516, -94.2622, 'DASSEL 3.4 SE')
# ('US1MNMK0011', 45.0777, -94.3157, 'DASSEL 0.4 S')
# ('US1MNMK0012', 45.3011, -94.4746, 'WATKINS 3.2 WSW')
# ('US1MNMK0013', 45.2964, -94.6074, 'EDEN VALLEY 3.6 SW')
# ('US1MNML0001', 46.1088, -93.7389, 'ONAMIA 4.3 NW')
# ('US1MNML0003', 46.2207, -93.8089, 'GARRISON 5.5 S')
# ('US1MNML0004', 45.6613, -93.5726, 'PRINCETON 6.3 N')
# ('US1MNML0007', 45.5852, -93.577, 'PRINCETON 1.1 NNE')
# ('US1MNMR0004', 45.9689, -94.3772, 'LITTLE FALLS 1.2 SW')
# ('US1MNMR0007', 45.819, -94.3917, 'ROYALTON 4.9 W')
# ('US1MNMR0012', 46.1446, -93.8944, 'HILLMAN 9.6 N')
# ('US1MNMR0013', 46.0679, -94.2479, 'LITTLE FALLS 8.0 NE')
# ('US1MNMR0017', 46.0261, -94.3543, 'LITTLE FALLS 3.0 N')
# ('US1MNMS0005', 48.2647, -96.8703, 'WARREN 6.6 NW')
# ('US1MNMS0008', 48.3561, -96.3346, 'NEWFOLDEN 0.2 W')
# ('US1MNMT0001', 43.6527, -94.4482, 'FAIRMONT 0.9 NE')
# ('US1MNMT0003', 43.6468, -94.8422, 'ALPHA 1.6 ENE')
# ('US1MNMT0004', 43.547, -94.469, 'FAIRMONT 6.7 S')
# ('US1MNMT0006', 43.645, -94.4486, 'FAIRMONT 0.7 E')
# ('US1MNMT0009', 43.8317, -94.7355, 'ODIN 2.5 S')
# ('US1MNMW0003', 43.6784, -92.9381, 'AUSTIN 1.9 ENE')
# ('US1MNMW0006', 43.6452, -92.5208, 'OSTRANDER 5.1 WNW')
# ('US1MNMW0007', 43.6755, -93.0286, 'AUSTIN 2.7 W')
# ('US1MNMY0002', 44.1247, -95.6998, 'SLAYTON 9.7 NNE')
# ('US1MNNB0002', 43.65, -95.9529, 'ADRIAN 1.5 NW')
# ('US1MNNB0004', 43.5871, -95.5386, 'WORTHINGTON 4.1 SE')
# ('US1MNNC0002', 44.2947, -94.4092, 'NEW ULM 3.1 ESE')
# ('US1MNNC0003', 44.2885, -94.0764, 'SAINT PETER 6.2 WSW')
# ('US1MNNC0006', 44.3125, -93.9854, 'SAINT PETER 1.5 SW')
# ('US1MNNC0007', 44.1723, -94.0123, 'NORTH MANKATO 1.3 ESE')
# ('US1MNNC0009', 44.2563, -94.0339, 'KASOTA 4.0 SW')
# ('US1MNNR0001', 47.2602, -96.2577, 'TWIN VALLEY 0.1 NE')
# ('US1MNOL0001', 43.9929, -92.4074, 'ROCHESTER 3.9 ESE')
# ('US1MNOL0004', 44.0569, -92.4348, 'ROCHESTER 3.6 NE')
# ('US1MNOL0005', 44.0116, -92.5293, 'ROCHESTER 2.5 W')
# ('US1MNOL0006', 44.0422, -92.4047, 'ROCHESTER 4.1 ENE')
# ('US1MNOL0007', 43.9555, -92.6324, 'BYRON 5.7 S')
# ('US1MNOL0009', 43.9768, -92.337, 'EYOTA 5.3 W')
# ('US1MNOL0010', 44.0458, -92.3703, 'ROCHESTER 5.8 ENE')
# ('US1MNOL0011', 43.9194, -92.5008, 'ROCHESTER 6.7 S')
# ('US1MNOL0012', 44.0954, -92.468, 'ROCHESTER 5.5 N')
# ('US1MNOL0015', 44.0208, -92.4863, 'ROCHESTER 0.5 NW')
# ('US1MNOL0016', 44.0738, -92.492, 'ROCHESTER 4.1 N')
# ('US1MNOL0018', 44.0397, -92.4375, 'ROCHESTER 2.6 NE')
# ('US1MNOL0027', 43.8534, -92.5907, 'STEWARTVILLE 5.1 W')
# ('US1MNOL0029', 44.0019, -92.3783, 'ROCHESTER 5.1 E')
# ('US1MNOL0030', 44.0837, -92.4832, 'ROCHESTER 4.7 N')
# ('US1MNOL0032', 44.0514, -92.4868, 'ROCHESTER 2.5 N')
# ('US1MNOL0034', 44.0378, -92.5342, 'ROCHESTER 3.2 WNW')
# ('US1MNOL0991', 44.0415, -92.0882, 'ELBA 4.7 SW')
# ('US1MNOT0001', 46.1308, -95.9187, 'DALTON 3.0 S')
# ('US1MNOT0002', 46.2966, -96.0655, 'FERGUS FALLS 0.9 NNE')
# ('US1MNOT0003', 46.2583, -95.7147, 'BATTLE LAKE 2S')
# ('US1MNOT0004', 46.5707, -96.116, 'PELICAN RAPIDS 1.4 W')
# ('US1MNOT0005', 46.2853, -96.0663, 'FERGUS FALLS 0.5 E')
# ('US1MNOT0006', 46.6597, -96.1122, 'PELICAN RAPIDS 6.3 NNW')
# ('US1MNOT0007', 46.3841, -95.3622, 'DEER CREEK 2.0 WSW')
# ('US1MNOT0009', 46.4393, -95.5887, 'OTTERTAIL 1.5 NW')
# ('US1MNOT0011', 46.2696, -95.6522, 'CLITHERALL 1.1 WSW')
# ('US1MNOT0013', 46.4264, -95.6683, 'RICHVILLE 5.8 SSW')
# ('US1MNOT0014', 46.1641, -95.706, 'BATTLE LAKE 8.3 S')
# ('US1MNOT0015', 46.6028, -95.7984, 'DENT 5.1 NW')
# ('US1MNOT0016', 46.3539, -96.0134, 'FERGUS FALLS 5.6 NNE')
# ('US1MNOT0017', 46.2125, -95.9948, 'FERGUS FALLS 6.3 SE')
# ('US1MNOT0018', 46.519, -95.6443, 'RICHVILLE 1.2 NW')
# ('US1MNOT0019', 46.3904, -95.3223, 'DEER CREEK 0.0 SW')
# ('US1MNOT0023', 46.5916, -95.5632, 'PERHAM 0.7 SE')
# ('US1MNOT0025', 46.3672, -95.9928, 'FERGUS FALLS 6.9 NE')
# ('US1MNOT0027', 46.292, -96.0758, 'FERGUS FALLS 0.5 N')
# ('US1MNOT0030', 46.2814, -95.957, 'FERGUS FALLS 5.7 E')
# ('US1MNPG0003', 48.07, -95.9197, 'GOODRIDGE 7.4 SW')
# ('US1MNPG0004', 48.1169, -96.1799, 'THIEF RIVER FALLS 0.3 NW')
# ('US1MNPK0001', 47.786, -96.5922, 'CROOKSTON 1.0 NE')
# ('US1MNPK0002', 47.5856, -96.1279, 'ERSKINE 7.6 SW')
# ('US1MNPK0008', 47.604, -96.1962, 'FERTILE 6.5 NE')
# ('US1MNPK0011', 47.5339, -96.2757, 'FERTILE 0.6 E')
# ('US1MNPK0013', 47.7778, -96.5939, 'CROOKSTON 0.6 ENE')
# ('US1MNPK0015', 47.6663, -96.1733, 'MENTOR 2.5 SSW')
# ('US1MNPK0018', 47.5395, -95.6262, 'LENGBY 1.7 NNE')
# ('US1MNPK0991', 47.6074, -96.0354, 'ERSKINE 4.1 SSW')
# ('US1MNPN0006', 46.1775, -92.7842, 'ASKOV 0.8 S')
# ('US1MNPN0011', 45.7806, -93.0734, 'PINE CITY 6.1 SW')
# ('US1MNPN0012', 46.0419, -92.973, 'HINCKLEY 3.0 NW')
# ('US1MNPN0015', 46.0063, -92.6333, 'HINCKLEY 14.0 E')
# ('US1MNPN0016', 46.1629, -92.8948, 'FINLAYSON 3.3 SSE')
# ('US1MNPP0002', 45.6134, -95.5395, 'STARBUCK 0.3 WNW')
# ('US1MNPP0003', 45.4847, -95.3783, 'GLENWOOD 11.5 S')
# ('US1MNPP0004', 45.5229, -95.7115, 'HANCOCK 4.4 ENE')
# ('US1MNPP0006', 45.7305, -95.3618, 'GLENWOOD 5.5 N')
# ('US1MNPS0001', 43.8759, -96.1406, 'EDGERTON 0.5 W')
# ('US1MNPS0004', 43.8516, -96.3916, 'JASPER 0.3 ESE')
# ('US1MNPS0006', 43.8744, -96.1333, 'EDGERTON 0.2 WSW')
# ('US1MNRC0001', 44.464, -93.5198, 'MONTGOMERY 3.2 ENE')
# ('US1MNRC0003', 44.4994, -93.4455, 'LONSDALE 1.9 NW')
# ('US1MNRC0005', 44.469, -93.1689, 'NORTHFIELD 0.9 NNW')
# ('US1MNRC0008', 44.3875, -93.2392, 'DUNDAS 3.2 SSW')
# ('US1MNRC0011', 44.52, -93.4847, 'NEW PRAGUE 4.8 ESE')
# ('US1MNRC0021', 44.4484, -93.1505, 'NORTHFIELD 0.8 SE')
# ('US1MNRC0027', 44.5153, -93.3997, 'LONSDALE 2.8 NNE')
# ('US1MNRC0028', 44.3774, -93.3862, 'FARIBAULT 7.6 NW')
# ('US1MNRC0030', 44.2994, -93.2773, 'FARIBAULT 0.1 NE')
# ('US1MNRM0001', 45.0208, -93.0542, 'KOHLMAN PARK')
# ('US1MNRM0002', 45.0263, -93.0079, 'NORTH SAINT PAUL 1.0 NNW')
# ('US1MNRM0005', 44.998, -93.14, 'ROSEVILLE 1.4 SSE')
# ('US1MNRM0006', 45.0438, -93.0232, 'WHITE BEAR LAKE 2.8 SSW')
# ('US1MNRM0007', 44.9589, -93.1703, 'SAINT PAUL 3.3 WNW')
# ('US1MNRM0008', 45.0784, -93.1491, 'ARDEN HILLS 1.0 ENE')
# ('US1MNRM0009', 44.93, -93.147, 'SAINT PAUL 2.4 WSW')
# ('US1MNRM0014', 45.0557, -93.2022, 'NEW BRIGHTON 0.7 SSE')
# ('US1MNRM0015', 45.035, -93.1862, 'ROSEVILLE 2.1 NW')
# ('US1MNRM0019', 45.0184, -93.1027, 'LITTLE CANADA 0.9 WSW')
# ('US1MNRM0020', 44.9571, -92.985, 'MAPLEWOOD 2.7 SE')
# ('US1MNRM0022', 44.9599, -93.1857, 'SAINT PAUL 4.1 WNW')
# ('US1MNRM0023', 45.0319, -93.0771, 'LITTLE CANADA 0.7 NE')
# ('US1MNRM0024', 45.0787, -93.0699, 'VADNAIS HEIGHTS 1.5 N')
# ('US1MNRM0030', 44.9718, -93.1031, 'SAINT PAUL 1.7 N')
# ('US1MNRM0031', 45.0199, -93.1468, 'ROSEVILLE 0.5 NE')
# ('US1MNRM0037', 44.9955, -93.0271, 'MAPLEWOOD 0.8 N')
# ('US1MNRM0039', 44.9715, -93.1605, 'SAINT PAUL 3.2 WNW')
# ('US1MNRM0041', 44.9768, -93.1865, 'SAINT PAUL 4.5 WNW')
# ('US1MNRM0045', 45.0259, -93.1451, 'ROSEVILLE 0.9 NNE')
# ('US1MNRM0046', 44.9935, -93.1119, 'ROSEVILLE 2.6 SE')
# ('US1MNRM0054', 44.9039, -93.1882, 'SAINT PAUL 5.1 SW')
# ('US1MNRM0056', 45.033, -93.1752, 'ROSEVILLE 1.6 NW')
# ('US1MNRM0057', 44.9564, -93.0837, 'SAINT PAUL MPCA')
# ('US1MNRM0061', 44.9374, -93.1852, 'SAINT PAUL 4.0 W')
# ('US1MNRM0063', 45.0241, -93.014, 'NORTH SAINT PAUL 1.0 NW')
# ('US1MNRM0065', 44.9019, -93.1727, 'SAINT PAUL 4.6 SW')
# ('US1MNRM0070', 45.0084, -93.141, 'ROSEVILLE 0.8 SE')
# ('US1MNRM0071', 45.1148, -93.1117, 'SHOREVIEW 2.4 NNE')
# ('US1MNRM0075', 45.1169, -93.1203, 'SHOREVIEW 2.4 NNE')
# ('US1MNRM0083', 45.1055, -93.0396, 'WHITE BEAR LAKE 2.1 NW')
# ('US1MNRM0084', 45.0019, -93.1703, 'ROSEVILLE 1.2 SW')
# ('US1MNRS0001', 48.8436, -95.7635, 'ROSEAU 0.1 SSW')
# ('US1MNRS0002', 48.8486, -95.7574, 'ROSEAU 0.4 NE')
# ('US1MNRS0003', 48.9988, -95.7678, 'ROSEAU 10.7 N')
# ('US1MNRS0006', 48.7771, -95.6247, 'ROSEAU 7.8 SE')
# ('US1MNRV0003', 44.7894, -95.0973, 'DANUBE 0.3 SE')
# ('US1MNRV0004', 44.6759, -94.7723, 'HECTOR 5.4 SSW')
# ('US1MNRV0005', 44.8844, -94.8188, 'BIRD ISLAND 9.0 NNE')
# ('US1MNRV0007', 44.8053, -94.5505, 'BUFFALO LAKE 5.7 NE')
# ('US1MNRV0008', 44.6654, -94.8544, 'BIRD ISLAND 7.2 SSE')
# ('US1MNRV0011', 44.8066, -95.1394, 'RENVILLE 3.7 ENE')
# ('US1MNRV0012', 44.6657, -95.1374, 'RENVILLE 9.3 SSE')
# ('US1MNRV0013', 44.7626, -94.8984, 'BIRD ISLAND 0.3 SW')
# ('US1MNRW0001', 44.5382, -95.0996, 'REDWOOD FALLS 0.9 E')
# ('US1MNRW0002', 44.5388, -95.1096, 'REDWOOD FALLS 0.4 E')
# ('US1MNRW0003', 44.4084, -95.4097, 'LUCAN 0.2 ESE')
# ('US1MNRW0008', 44.3923, -95.1872, 'WABASSO 3.4 ESE')
# ('US1MNSB0004', 44.6877, -94.0384, 'GREEN ISLE 1.7 WNW')
# ('US1MNSB0005', 44.6016, -94.0663, 'ARLINGTON 0.7 SE')
# ('US1MNSC0002', 44.7125, -93.4636, 'PRIOR LAKE 2.0 W')
# ('US1MNSC0003', 44.5923, -93.3192, 'LAKEVILLE 6.8 SSW')
# ('US1MNSC0006', 44.7121, -93.4029, 'PRIOR LAKE 2.0 ESE')
# ('US1MNSC0009', 44.733, -93.3337, 'SAVAGE 2.1 SE')
# ('US1MNSC0010', 44.6942, -93.6127, 'JORDAN 2.3 NNE')
# ('US1MNSC0011', 44.6075, -93.7991, 'BELLE PLAINE 1.9 WSW')
# ('US1MNSC0013', 44.5726, -93.3528, 'ELKO NEW MARKET 0.8 WNW')
# ('US1MNSC0017', 44.7554, -93.4023, 'SHAKOPEE 3.9 ESE')
# ('US1MNSC0018', 44.7854, -93.5503, 'SHAKOPEE 3.7 WNW')
# ('US1MNSC0019', 44.7729, -93.5237, 'SHAKOPEE 2.3 W')
# ('US1MNSC0021', 44.5608, -93.3132, 'ELKO NEW MARKET 1.3 ESE')
# ('US1MNSC0023', 44.7367, -93.4236, 'PRIOR LAKE 1.0 NE')
# ('US1MNSC0025', 44.5849, -93.4314, 'ELKO NEW MARKET 4.8 WNW')
# ('US1MNSC0033', 44.7817, -93.5287, 'SHAKOPEE 2.6 W')
# ('US1MNSE0002', 44.0917, -93.2138, 'OWATONNA 0.8 E')
# ('US1MNSE0003', 43.8705, -93.3036, 'ELLENDALE 0.3 SW')
# ('US1MNSE0005', 44.1121, -93.2099, 'OWATONNA 1.7 NE')
# ('US1MNSE0006', 44.0968, -93.2045, 'OWATONNA 1.3 ENE')
# ('US1MNSE0010', 43.9565, -93.2522, 'OWATONNA 9.4 S')
# ('US1MNSE0990', 44.088, -93.216, 'OWATONNA 0.7 ESE')
# ('US1MNSH0001', 45.552, -93.643, 'PRINCETON 3.2 WSW')
# ('US1MNSH0010', 45.4141, -93.6919, 'BIG LAKE 5.6 NNE')
# ('US1MNSH0012', 45.2943, -93.6092, 'ELK RIVER 3.3 SW')
# ('US1MNSH0015', 45.4421, -93.6731, 'BIG LAKE 7.7 NNE')
# ('US1MNSH0017', 45.433, -93.5993, 'ZIMMERMAN 0.6 S')
# ('US1MNSH0018', 45.3893, -93.6842, 'BIG LAKE 4.4 NE')
# ('US1MNSH0019', 45.4067, -93.8839, 'BECKER 1.9 NNW')
# ('US1MNSH0020', 45.3803, -93.781, 'BIG LAKE 3.2 NNW')
# ('US1MNSH0023', 45.4579, -93.993, 'CLEAR LAKE 0.7 NNE')
# ('US1MNSH0025', 45.3062, -93.5783, 'ELK RIVER 1.8 SSW')
# ('US1MNSH0028', 45.2596, -93.5376, 'ELK RIVER 5.2 SSE')
# ('US1MNSH0985', 45.5521, -93.6448, 'PRINCETON 3.3 WSW')
# ('US1MNSL0002', 46.9312, -91.9428, 'DULUTH 12.8 NE')
# ('US1MNSL0003', 46.7932, -92.1887, 'HERMANTOWN 2.6 ESE')
# ('US1MNSL0005', 46.8153, -92.0637, 'DULUTH 3.0 NE')
# ('US1MNSL0006', 46.93, -92.1439, 'HERMANTOWN 9.3 NNE')
# ('US1MNSL0007', 47.3717, -92.877, 'HIBBING 3.8 ESE')
# ('US1MNSL0009', 46.7977, -92.1037, 'DULUTH 1.0 N')
# ('US1MNSL0011', 46.8382, -92.0827, 'DULUTH 4.1 NNE')
# ('US1MNSL0015', 47.4856, -92.8869, 'CHISHOLM 0.4 WSW')
# ('US1MNSL0018', 46.8032, -92.1124, 'DULUTH 1.4 NNW')
# ('US1MNSL0020', 46.8131, -92.0556, 'DULUTH 3.2 NE')
# ('US1MNSL0027', 47.3941, -93.0018, 'HIBBING 2.5 W')
# ('US1MNSL0030', 46.8109, -92.0918, 'DULUTH 2.0 NNE')
# ('US1MNSL0034', 47.7815, -92.9943, 'COOK 14.8 WSW')
# ('US1MNSL0035', 47.033, -92.2367, 'DULUTH 18.3 NNW')
# ('US1MNSL0038', 46.8549, -92.0487, 'DULUTH 5.6 NNE')
# ('US1MNSL0050', 46.8351, -92.1051, 'DULUTH 3.6 N')
# ('US1MNSL0051', 46.8135, -92.0726, 'DULUTH 2.6 NE')
# ('US1MNSL0069', 46.8619, -92.0595, 'DULUTH 5.9 NNE')
# ('US1MNSL0070', 46.8082, -92.0911, 'DULUTH 1.9 NNE')
# ('US1MNSL0074', 46.8041, -92.1125, 'DULUTH 1.5 NNW')
# ('US1MNSL0076', 46.8757, -92.029, 'DULUTH 7.4 NNE')
# ('US1MNSL0077', 46.8127, -92.071, 'DULUTH 2.6 NE')
# ('US1MNSL0080', 47.9276, -91.8028, 'WINTON 0.1 WSW')
# ('US1MNSL0082', 46.8457, -92.4691, 'SAGINAW 1.5 SW')
# ('US1MNSL0084', 46.8684, -92.0285, 'DULUTH 6.9 NNE')
# ('US1MNSL0090', 46.8544, -92.0175, 'DULUTH 6.5 NE')
# ('US1MNSL0095', 48.4498, -93.0542, 'KABETOGAMA 1.5 NW')
# ('US1MNSL0096', 46.9253, -92.5632, 'CULVER 0.2 W')
# ('US1MNSL0100', 46.8508, -92.0196, 'DULUTH 6.2 NE')
# ('US1MNSL0102', 46.8303, -92.1127, 'DULUTH 3.3 N')
# ('US1MNSL0104', 47.1531, -91.9041, 'DULUTH 27.3 NNE')
# ('US1MNSL0105', 46.9468, -92.0393, 'DULUTH 11.8 NNE')
# ('US1MNSL0107', 46.9941, -92.3126, 'DULUTH 17.6 NNW')
# ('US1MNSL0108', 47.4615, -92.6313, 'IRON JUNCTION 3.4 NNW')
# ('US1MNSL0109', 46.705, -92.2267, 'DULUTH 7.9 SW')
# ('US1MNSL0110', 46.8425, -92.0844, 'DULUTH 4.2 NNE')
# ('US1MNSL0115', 47.1514, -92.3577, 'COTTON 5.7 ESE')
# ('US1MNSL0122', 46.6928, -92.21, 'MORGAN PARK')
# ('US1MNSL0124', 47.7074, -91.9306, 'BABBITT 4.4 N')
# ('US1MNSL0125', 46.826, -92.0394, 'DULUTH 4.3 NE')
# ('US1MNSL0129', 46.9853, -92.2429, 'DULUTH 15.4 NNW')
# ('US1MNSL0139', 46.77, -92.0883, 'DULUTH 1.2 SE')
# ('US1MNSL0142', 46.8116, -92.1472, 'DULUTH 2.8 NW')
# ('US1MNSR0001', 45.7478, -94.265, 'RICE 1.5 WSW')
# ('US1MNSR0003', 45.5779, -94.247, 'SAINT CLOUD 5.4 WNW')
# ('US1MNSR0004', 45.5668, -94.2366, 'SAINT CLOUD 4.7 W')
# ('US1MNSR0006', 45.6852, -94.5525, 'ALBANY 4.0 N')
# ('US1MNSR0007', 45.6181, -94.2338, 'SARTELL 1.3 WSW')
# ('US1MNSR0008', 45.501, -95.1256, 'BROOTEN 0.5 W')
# ('US1MNSR0009', 45.6018, -94.1991, 'SARTELL 1.4 SSE')
# ('US1MNSR0015', 45.5823, -94.1896, 'SAINT CLOUD 3.1 NW')
# ('US1MNSR0016', 45.4185, -94.5632, 'RICHMOND 3.4 SW')
# ('US1MNSR0020', 45.5637, -94.3074, 'SAINT JOSEPH 0.2 N')
# ('US1MNSR0024', 45.3517, -94.7312, 'PAYNESVILLE 1.9 SSW')
# ('US1MNSR0025', 45.4566, -94.4473, 'COLD SPRING 0.8 W')
# ('US1MNSR0027', 45.6861, -95.0973, 'SAUK CENTRE 7.8 WSW')
# ('US1MNSR0029', 45.5744, -94.5554, 'ALBANY 3.8 S')
# ('US1MNSR0032', 45.5755, -94.1758, 'SAINT CLOUD 2.2 NW')
# ('US1MNSR0033', 45.5961, -94.2461, 'SARTELL 2.6 SW')
# ('US1MNSV0002', 45.5891, -95.9265, 'MORRIS 1.1 WNW')
# ('US1MNSV0003', 45.5771, -95.8968, 'MORRIS 0.7 SSE')
# ('US1MNSV0004', 45.7165, -96.0604, 'DONNELLY 2.9 NW')
# ('US1MNSV0006', 45.5889, -96.1824, 'CHOKIO 1.2 NNW')
# ('US1MNSW0001', 45.3403, -95.9784, 'APPLETON 9.9 NNE')
# ('US1MNTD0002', 46.3259, -95.0854, 'HEWITT 0.3 ENE')
# ('US1MNTD0003', 45.9048, -94.6506, 'SWANVILLE 0.6 SSW')
# ('US1MNTD0004', 46.3406, -95.0945, 'HEWITT 1.1 N')
# ('US1MNTD0005', 45.9654, -94.8916, 'LONG PRAIRIE 1.6 WSW')
# ('US1MNTD0007', 46.0018, -94.6977, 'LONG PRAIRIE 8.1 ENE')
# ('US1MNTD0009', 46.1279, -94.9467, 'CLARISSA 0.1 ESE')
# ('US1MNWB0003', 44.4283, -92.2658, 'LAKE CITY 1.0 SE')
# ('US1MNWB0004', 44.2389, -92.4551, 'ZUMBRO FALLS 3.5 SSW')
# ('US1MNWB0006', 44.4408, -92.2758, 'LAKE CITY 0.1 E')
# ('US1MNWB0007', 44.3828, -92.035, 'WABASHA 0.9 NNE')
# ('US1MNWC0002', 44.0512, -93.6613, 'WASECA 8.2 WSW')
# ('US1MNWC0005', 44.0945, -93.4929, 'WASECA 0.9 NNE')
# ('US1MNWC0007', 44.1953, -93.4767, 'WASECA 7.9 N')
# ('US1MNWD0001', 46.3974, -95.0159, 'VERNDALE 0.2 WNW')
# ('US1MNWD0002', 46.7569, -95.1021, 'MENAHGA 0.7 N')
# ('US1MNWD0003', 46.4259, -94.8626, 'STAPLES 5.5 NNW')
# ('US1MNWD0005', 46.3904, -95.0689, 'VERNDALE 2.3 WSW')
# ('US1MNWD0007', 46.4853, -95.1634, 'WADENA 3.3 NNW')
# ('US1MNWD0980', 46.7465, -95.1405, 'MENAHGA 2.1 WSW')
# ('US1MNWG0001', 44.9172, -92.919, 'WOODBURY 0.8 NNE')
# ('US1MNWG0002', 44.8233, -92.9389, 'COTTAGE GROVE 0.8 NW')
# ('US1MNWG0004', 44.8478, -92.8026, 'AFTON 4.0 S')
# ('US1MNWG0005', 44.9417, -92.8629, 'WOODBURY 3.8 NE')
# ('US1MNWG0006', 45.2458, -92.8127, 'MARINE ON SAINT CROIX 3.7 NNW')
# ('US1MNWG0008', 45.0361, -92.954, 'PINE SPRINGS 0.1 SSE')
# ('US1MNWG0009', 45.0561, -92.8243, 'STILLWATER 0.2 E')
# ('US1MNWG0011', 45.2412, -93.0085, 'FOREST LAKE 2.8 SSW')
# ('US1MNWG0012', 45.045, -92.8579, 'STILLWATER 1.7 WSW')
# ('US1MNWG0014', 45.0318, -92.9165, 'LAKE ELMO 2.7 NNW')
# ('US1MNWG0015', 44.8465, -92.9909, 'SAINT PAUL PARK 0.7 NNE')
# ('US1MNWG0016', 44.9305, -92.9249, 'WOODBURY 1.7 N')
# ('US1MNWG0017', 45.2022, -92.8814, 'MARINE ON SAINT CROIX 4.9 W')
# ('US1MNWG0018', 44.9991, -92.8821, 'LAKE ELMO 1.1 ENE')
# ('US1MNWG0019', 45.0242, -92.9656, 'PINE SPRINGS 1.0 SSW')
# ('US1MNWG0020', 45.0707, -92.8085, 'STILLWATER 1.4 NE')
# ('US1MNWG0021', 45.0171, -92.9478, 'LAKE ELMO 2.7 NW (81)')
# ('US1MNWG0022', 44.9577, -92.9842, 'OAKDALE 2.3 SSW (151)')
# ('US1MNWG0023', 44.9472, -92.9783, 'WOODBURY 4.0 NW (122)')
# ('US1MNWG0024', 45.0483, -92.971, 'MAHTOMEDI 1.0 SSW')
# ('US1MNWG0027', 45.1674, -92.9788, 'HUGO 1.0 W')
# ('US1MNWG0028', 44.8259, -92.9711, 'COTTAGE GROVE 2.3 WNW')
# ('US1MNWG0033', 44.8382, -92.9359, 'COTTAGE GROVE 1.6 NNW')
# ('US1MNWG0035', 45.0309, -92.842, 'OAK PARK HEIGHTS 2.4 W')
# ('US1MNWG0038', 45.2401, -93.0055, 'FOREST LAKE 2.5 WSW')
# ('US1MNWG0040', 44.9236, -92.7921, 'AFTON 1.8 NE')
# ('US1MNWG0042', 44.8745, -92.9713, 'WOODBURY 3.2 SW')
# ('US1MNWG0043', 44.8394, -92.928, 'COTTAGE GROVE 1.6 N')
# ('US1MNWG0045', 44.837, -92.9205, 'COTTAGE GROVE 1.5 NNE')
# ('US1MNWG0046', 44.9741, -92.8186, 'STILLWATER 5.7 S')
# ('US1MNWG0047', 44.9, -92.7858, 'AFTON 1.6 E')
# ('US1MNWG0051', 44.9074, -92.9285, 'WOODBURY 0.3 WNW')
# ('US1MNWG0052', 44.844, -92.9924, 'ST PAUL PARK 0.6 NNE')
# ('US1MNWG0053', 44.831, -92.9541, 'COTTAGE GROVE 1.7 NW')
# ('US1MNWG0056', 44.9085, -92.9347, 'WOODBURY 0.6 WNW')
# ('US1MNWG0058', 45.1052, -92.9729, 'DELLWOOD 0.5 NNW')
# ('US1MNWG0060', 45.2475, -92.77, 'SCANDIA 2.8 E')
# ('US1MNWG0066', 45.043, -92.9657, 'MAHTOMEDI 1.3 S')
# ('US1MNWK0001', 46.4366, -96.6847, 'KENT 0.2 SW')
# ('US1MNWK0002', 46.0952, -96.4064, 'CAMPBELL 0.2 SSW')
# ('US1MNWK0003', 46.2785, -96.5929, 'BRECKENRIDGE 0.9 NNW')
# ('US1MNWK0005', 46.5692, -96.7154, 'WOLVERTON 1.1 ENE')
# ('US1MNWN0002', 44.0171, -91.6098, 'WINONA 3.8 SE')
# ('US1MNWN0003', 43.9858, -91.8719, 'LEWISTON 0.2 NW')
# ('US1MNWN0004', 44.115, -91.8473, 'ROLLINGSTONE 1.8 NW')
# ('US1MNWN0005', 44.0303, -91.7684, 'WINONA 5.1 WSW')
# ('US1MNWN0006', 44.0259, -91.769, 'STOCKTON 0.1 SSE')
# ('US1MNWN0007', 43.8933, -91.6933, 'RUSHFORD 6.3 NNE')
# ('US1MNWN0009', 44.0825, -91.7338, 'MINNESOTA CITY 1.1 SE')
# ('US1MNWN0011', 44.0338, -91.6795, 'WINONA 1.3 SSW')
# ('US1MNWR0006', 45.0969, -93.7636, 'ROCKFORD 1.2 WNW')
# ('US1MNWR0008', 45.2012, -93.6658, 'SAINT MICHAEL 1.3 E')
# ('US1MNWR0011', 45.2394, -93.6669, 'ALBERTVILLE 0.3 NW')
# ('US1MNWR0013', 45.0447, -93.9107, 'MONTROSE 1.6 SSE')
# ('US1MNWR0015', 45.3392, -93.6806, 'MONTICELLO 6.4 ENE (45)')
# ('US1MNWR0019', 45.1031, -93.7337, 'ROCKFORD 1.0 NE')
# ('US1MNWR0020', 45.229, -93.9985, 'MAPLE LAKE 0.5 SE')
# ('US1MNWR0025', 45.2082, -93.6528, 'SAINT MICHAEL 2.0 ENE')
# ('US1MNWR0029', 45.1841, -93.8718, 'BUFFALO 0.5 NW')
# ('US1MNWR0031', 45.1753, -93.7338, 'SAINT MICHAEL 2.7 SW')
# ('US1MNWR0035', 45.2536, -93.6592, 'OTSEGO 2.1 WSW')
# ('US1MNWR0037', 45.2067, -93.8332, 'BUFFALO 2.4 NE')
# ('US1MNWR0038', 45.3241, -93.8913, 'MONTICELLO 4.8 WNW')
# ('US1MNWR0040', 45.3479, -94.0337, 'CLEARWATER 5.4 SSE')
# ('US1MNWR0041', 45.2169, -93.6776, 'SAINT MICHAEL 1.3 NNE')
# ('US1MNWR0042', 45.0745, -94.0812, 'HOWARD LAKE 1.2 NW')
# ('US1MNWR0047', 45.3066, -93.9806, 'MAPLE LAKE 5.2 NNE')
# ('US1MNWR0048', 45.167, -93.7053, 'SAINT MICHAEL 2.5 SSW')
# ('US1MNWW0004', 44.0956, -94.6018, 'SAINT JAMES 7.8 N')
# ('US1MNWW0005', 43.9774, -94.6301, 'SAINT JAMES 0.5 SSW')
# ('US1MNYM0003', 44.8431, -95.7467, 'CLARKFIELD 4.7 NE')
# ('US1MNYM0004', 44.8933, -95.7125, 'MONTEVIDEO 4.0 S')
# ('US1MNYM0005', 44.7863, -95.9704, 'BOYD 5.6 SW')
# ('US1MNYM0006', 44.7131, -96.2807, 'CANBY 0.6 W')
# ('USC00210018', 47.2992, -96.5161, 'ADA')
# ('USC00210050', 48.3006, -95.9817, 'AGASSIZ REFUGE')
# ('USC00210059', 46.5258, -93.6675, 'AITKIN 2E')
# ('USC00210075', 43.6064, -93.3019, 'ALBERT LEA 3 SE')
# ('USC00210080', 43.6667, -93.3, 'ALBERT LEA 3 E')
# ('USC00210096', 46.9667, -92.5833, 'ALBORN')
# ('USC00210116', 45.8967, -95.3658, 'ALEXANDRIA WTP')
# ('USC00210128', 47.5333, -92.1167, 'ALLEN JUNCTION')
# ('USC00210137', 44.0833, -93.75, 'ALMA CITY')
# ('USC00210146', 44.0633, -92.0397, 'ALTURA 5W')
# ('USC00210157', 43.8836, -94.1664, 'AMBOY')
# ('USC00210190', 45.2533, -93.2928, 'ANDOVER 1N')
# ('USC00210195', 48.1, -96.7, 'ANGUS 1 N')
# ('USC00210252', 48.3311, -96.8253, 'ARGYLE')
# ('USC00210287', 45.3856, -96.1258, 'ARTICHOKE LAKE 1 E')
# ('USC00210317', 46.25, -95.7667, 'ASHBY')
# ('USC00210355', 43.6542, -92.9739, 'AUSTIN WASTE WTP FACILITY')
# ('USC00210387', 47.7122, -91.9533, 'BABBITT')
# ('USC00210390', 47.6833, -91.9167, 'BABBITT 2 SE')
# ('USC00210515', 48.7094, -94.5853, 'BAUDETTE')
# ('USC00210520', 48.4167, -94.5667, 'BAUDETTE 21 SSE')
# ('USC00210541', 45.55, -96.7167, 'BEARDSLEY')
# ('USC00210546', 47.3333, -95.7667, 'BEAULIEU')
# ('USC00210559', 44.15, -92.0167, 'BEAVER')
# ('USC00210564', 47.2003, -91.3672, 'BEAVER BAY 5SW')
# ('USC00210628', 44.6333, -93.7667, 'BELLE PLAINE')
# ('USC00210643', 47.5353, -94.8267, 'BEMIDJI')
# ('USC00210667', 45.3167, -95.6167, 'BENSON')
# ('USC00210746', 48.1969, -93.7994, 'BIG FALLS')
# ('USC00210754', 47.7, -93.55, 'BIGFORK 5 ESE')
# ('USC00210768', 43.9167, -95.05, 'BINGHAM LAKE')
# ('USC00210783', 44.7667, -94.9, 'BIRD ISLAND')
# ('USC00210803', 47.7167, -94.5667, 'BLACKDDCK RS')
# ('USC00210809', 47.6714, -94.5175, 'BLACKDUCK')
# ('USC00210811', 44.6, -93.8667, 'BLAKELEY')
# ('USC00210826', 45.8667, -94.35, 'BLANCHARD PWR STN')
# ('USC00210839', 43.9167, -93.05, 'BLOOMING PRAIRIE')
# ('USC00210852', 43.6453, -94.0936, 'BLUE EARTH')
# ('USC00210855', 43.6236, -94.0947, 'BLUE EARTH 1S')
# ('USC00210934', 46.3667, -94.1833, 'BRAINERD')
# ('USC00210939', 46.3433, -94.2086, 'BRAINERD')
# ('USC00210973', 46.2681, -96.5914, 'BRECKENRIDGE MN')
# ('USC00210974', 46.3047, -96.5217, 'BRECKENRIDGE 3E')
# ('USC00210981', 43.5439, -93.8422, 'BRICELYN')
# ('USC00210989', 47.2472, -91.8625, 'BRIMSON 2S')
# ('USC00211063', 45.5958, -96.8283, 'BROWNS VALLEY')
# ('USC00211065', 44.7336, -94.3417, 'BROWNTON WWTP')
# ('USC00211074', 46.3003, -92.5336, 'BRUNO 7ENE')
# ('USC00211107', 45.1969, -93.84, 'BUFFALO 2NE')
# ('USC00211174', 44.0908, -92.64, 'BYRON 4NORTH')
# ('USC00211198', 43.6308, -91.5028, 'CALEDONIA')
# ('USC00211227', 45.5506, -93.1264, 'CAMBRIDGE 5ESE')
# ('USC00211245', 46.0958, -96.4092, 'CAMPBELL')
# ('USC00211250', 48.61, -95.1817, 'CAMP NORRIS DNR')
# ('USC00211263', 44.7183, -96.2697, 'CANBY')
# ('USC00211278', 44.4828, -92.9133, 'CANNON FALLS 2SW')
# ('USC00211303', 48.9511, -96.4639, 'CARIBOU 2 S')
# ('USC00211310', 45.9653, -95.3386, 'CARLOS 2 WSW')
# ('USC00211323', 44.75, -93.5833, 'CARVER')
# ('USC00211374', 47.3847, -94.6147, 'CASS LAKE')
# ('USC00211390', 45.3222, -93.2844, 'CEDAR')
# ('USC00211417', 45.1667, -93.0667, 'CENTERVILLE LAKE')
# ('USC00211422', 47.8664, -93.0267, 'CELINA 2E')
# ('USC00211426', 48.7, -94.35, 'CENTRAL')
# ('USC00211448', 44.8497, -93.5644, 'CHANHASSEN WSFO')
# ('USC00211465', 44.8, -93.5833, 'CHASKA')
# ('USC00211468', 44.8131, -93.6311, 'CHASKA 2NW')
# ('USC00211489', 43.8333, -92.2, 'CHATFIELD')
# ('USC00211537', 44.4333, -92.6333, 'CLAYBANK')
# ('USC00211561', 45.45, -94.0, 'CLEAR LAKE')
# ('USC00211585', 45.4167, -94.0833, 'CLEARWATER')
# ('USC00211630', 46.7053, -92.5239, 'CLOQUET')
# ('USC00211669', 45.05, -94.25, 'COKATO')
# ('USC00211675', 47.2667, -93.4667, 'COLERAINE')
# ('USC00211691', 45.5794, -94.3919, "COLLEGEVILLE ST JOHN'S")
# ('USC00211718', 44.1167, -94.8167, 'COMFREY 4 E')
# ('USC00211771', 47.8947, -92.5336, 'COOK 8NE')
# ('USC00211773', 47.8786, -92.9328, 'COOK 12 W')
# ('USC00211776', 47.8667, -93.0667, 'COOK 18 W')
# ('USC00211787', 45.1667, -93.3333, 'COON CREEK FARM')
# ('USC00211812', 45.2333, -96.1667, 'CORRELL')
# ('USC00211840', 47.1686, -92.4628, 'COTTON')
# ('USC00211857', 48.2667, -92.4667, 'CRANE LAKE RS')
# ('USC00211880', 46.6667, -92.8333, 'CROMWELL CARLTON')
# ('USC00211886', 47.7833, -96.6167, 'CROOKSTON')
# ('USC00211891', 47.8014, -96.6031, 'CROOKSTON NW EXP STN')
# ('USC00211935', 44.9333, -93.5833, 'CRYSTAL BAY')
# ('USC00211963', 47.5167, -94.0167, 'CUT FOOT SIOUX RANGER')
# ('USC00211979', 44.0833, -95.6667, 'CURRIE')
# ('USC00212015', 46.125, -95.9089, 'DALTON 3S')
# ('USC00212023', 45.0419, -94.2781, 'DASSEL 3SE')
# ('USC00212038', 44.9317, -96.045, 'DAWSON')
# ('USC00212050', 46.8997, -94.3872, 'DEEP PORTAGE')
# ('USC00212088', 45.0417, -93.7908, 'DELANO')
# ('USC00212130', 44.9297, -93.5225, 'DEEPHAVEN LK MINNETONK')
# ('USC00212142', 46.8372, -95.8375, 'DETROIT LAKES 1 NNE')
# ('USC00212146', 46.8575, -95.6067, 'DETROIT LAKES 12E')
# ('USC00212156', 46.9611, -96.6531, 'DILWORTH 7 NNE')
# ('USC00212166', 44.0317, -92.8692, 'DODGE CTR')
# ('USC00212222', 48.5667, -97.15, 'DRAYTON N DAK 2 NE')
# ...
# ('USC00213587', 46.8833, -96.25, 'HAWLEY 3 NE')
# ('USC00213588', 46.85, -96.3333, 'HAWLEY 2 SW')
# ('USC00213596', 44.5, -92.55, 'HAY CREEK')
# ('USC00213678', 44.5356, -93.97, 'HENDERSON 3W')
# ('USC00213708', 45.8, -96.15, 'HERMAN')
# ('USC00213727', 47.4333, -92.9667, 'HIBBING PWR SUBSTN')
# ('USC00213756', 48.0667, -95.85, 'HIGH LANDING 2 NW')
# ('USC00213764', 46.9833, -93.6, 'HILL CITY RS')
# ('USC00213793', 45.9919, -92.9928, 'HINCKLEY')
# ('USC00213795', 46.0167, -92.95, 'HINCKLEY')
# ('USC00213808', 43.7636, -91.3481, 'HOKAH WWTP')
# ('USC00213812', 43.7956, -91.4264, 'HOKAH 4NW')
# ('USC00213863', 46.4675, -92.3903, 'HOLYOKE')
# ('USC00213913', 47.8333, -90.0, 'HOVLAND')
# ('USC00213921', 47.5833, -92.1333, 'HOYT LAKES 5 N')
# ('USC00213962', 44.9089, -94.3675, 'HUTCHINSON 1 N')
# ('USC00213965', 44.8978, -94.3719, 'HUTCHINSON 2')
# ('USC00214008', 48.6236, -93.8992, 'INDUS 3 W')
# ('USC00214066', 47.6333, -91.3333, 'ISABELLA')
# ('USC00214068', 47.6181, -91.3753, 'ISABELLA 1 W')
# ('USC00214077', 47.5933, -91.6514, 'ISABELLA 14W')
# ('USC00214093', 47.0239, -92.07, 'ISLAND LAKE 4E')
# ('USC00214096', 46.9833, -92.2333, 'ISLAND LAKE RSVR')
# ('USC00214102', 46.1333, -93.4667, 'ISLE')
# ('USC00214103', 46.3197, -93.5014, 'ISLE 12N')
# ('USC00214106', 47.2256, -95.1919, 'ITASCA UNIV OF MINN')
# ('USC00214176', 44.65, -93.6356, 'JORDAN 1SSW')
# ('USC00214191', 48.4089, -93.0483, 'KABETOGAMA')
# ('USC00214213', 48.5833, -96.5167, 'KARLSTAD')
# ('USC00214215', 48.5558, -96.48, 'KARLSTAD 2SE')
# ('USC00214233', 47.9422, -94.4553, 'KELLIHER')
# ('USC00214306', 48.5011, -92.6444, 'KETTLE FALLS')
# ('USC00214373', 45.3533, -94.3056, 'KIMBALL 3N')
# ('USC00214376', 43.8333, -95.5, 'KINBRAE')
# ('USC00214410', 45.0167, -95.8667, 'LAC QUI PARLE DAM')
# ('USC00214418', 43.8658, -91.31, 'LA CRESCENT DAM 7')
# ('USC00214431', 48.7244, -96.6214, 'LAKE BRONSON')
# ('USC00214433', 48.7242, -96.6217, 'LAKE BRONSON DAM')
# ('USC00214438', 44.4364, -92.2792, 'LAKE CITY')
# ('USC00214441', 44.1, -94.2, 'LAKE CRYSTAL')
# ('USC00214445', 45.0, -94.25, 'LAKE JENNIE')
# ('USC00214453', 43.7022, -95.1519, 'LAKEFIELD 2NE')
# ('USC00214534', 43.9983, -95.9494, 'LAKE WILSON')
# ('USC00214543', 43.6833, -95.1833, 'LAMBERT')
# ('USC00214546', 44.2394, -95.3153, 'LAMBERTON SW RSCH & OUTREACH C')
# ('USC00214563', 43.7203, -91.9717, 'LANESBORO')
# ('USC00214564', 43.7297, -91.9372, 'LANESBORO 2NE')
# ('USC00214641', 44.3833, -93.7167, 'LE CTR 2 SE')
# ('USC00214652', 47.2467, -94.2228, 'LEECH LAKE')
# ('USC00214688', 47.7333, -95.2167, 'LEONARD 8 NE')
# ('USC00214692', 44.8592, -94.0503, 'LESTER PRAIRIE 2S')
# ('USC00214711', 43.5167, -92.5, 'LE ROY')
# ('USC00214721', 44.4697, -93.9025, 'LE SUEUR')
# ('USC00214778', 45.1278, -94.5347, 'LITCHFIELD')
# ('USC00214793', 46.0039, -94.345, 'LITTLE FALLS 2NNE')
# ('USC00214798', 45.9833, -94.35, 'LITTLE FALLS WTR WKS')
# ('USC00214806', 48.4, -93.55, 'LITTLEFORK RS')
# ('USC00214809', 48.3681, -93.7214, 'LITTLEFORK 10 SW')
# ('USC00214861', 45.9647, -94.8892, 'LONG PRAIRIE')
# ('USC00214884', 44.9783, -93.2469, 'LOWER ST ANTHONY FALLS')
# ('USC00214914', 47.5833, -90.75, 'LUTSEN')
# ('USC00214918', 47.6981, -90.6656, 'LUTSEN 3NNE')
# ('USC00214937', 43.6658, -96.2022, 'LUVERNE')
# ('USC00214987', 44.3667, -95.8667, 'LYND #1')
# ('USC00214989', 44.3667, -95.8667, 'LYND #2')
# ('USC00214990', 43.5244, -91.7614, 'MABEL')
# ('USC00214994', 45.0025, -96.1661, 'MADISON WWTP')
# ('USC00215012', 47.3169, -95.9692, 'MAHNOMEN')
# ('USC00215020', 47.4667, -92.9833, 'MAHONING MINE')
# ('USC00215073', 44.1542, -94.0211, 'MANKATO')
# ('USC00215081', 48.6333, -94.0333, 'MANITOU')
# ('USC00215088', 44.1667, -94.0167, 'MANKATO')
# ('USC00215089', 44.1672, -93.9103, 'MANKATO 4E')
# ('USC00215136', 45.0, -93.65, 'MAPLE PLAIN')
# ('USC00215146', 44.8333, -92.95, 'MAPLEWOOD')
# ('USC00215175', 47.6308, -93.6522, 'MARCELL 5NE')
# ('USC00215204', 44.4717, -95.7903, 'MARSHALL')
# ('USC00215224', 44.3333, -92.5, 'MAZEPPA')
# ('USC00215298', 46.9833, -92.7333, 'MEADOWLANDS 9 S')
# ('USC00215311', 44.1667, -93.2333, 'MEDFORD')
# ('USC00215325', 45.6772, -94.8019, 'MELROSE')
# ('USC00215392', 45.7533, -93.6617, 'MILACA')
# ('USC00215400', 45.1219, -95.9269, 'MILAN 1NW')
# ('USC00215424', 44.9667, -93.3333, 'MINNEAPOLIS #1')
# ('USC00215433', 44.9833, -93.3, 'MINNEAPOLIS WB DWTN')
# ('USC00215482', 44.5631, -95.9969, 'MINNEOTA')
# ('USC00215486', 43.5833, -91.8, 'MINNESOTA CITY')
# ('USC00215488', 44.16, -91.8122, 'MINNESOTA CITY DAM 5')
# ('USC00215533', 47.95, -94.2167, 'MIZPAH')
# ('USC00215563', 44.9342, -95.7458, 'MONTEVIDEO 1SW')
# ('USC00215571', 44.4597, -93.6631, 'MONTGOMERY')
# ('USC00215584', 46.8667, -96.7667, 'MOREHEAD')
# ('USC00215586', 46.8875, -96.7483, 'MOORHEAD')
# ('USC00215589', 46.8667, -96.75, 'MOORHEAD ST TEACHERS C')
# ('USC00215590', 44.4175, -94.9217, 'MORGAN')
# ('USC00215598', 46.4378, -92.7578, 'MOOSE LAKE 1 SSE')
# ('USC00215603', 46.45, -92.7667, 'MOOSE LAKE RS')
# ('USC00215615', 45.8775, -93.3147, 'MORA')
# ('USC00215638', 45.59, -95.8744, 'MORRIS W CNTRL RSCH & OUTREACH')
# ('USC00215665', 44.95, -93.65, 'MOUND')
# ('USC00215677', 47.5333, -92.6, 'MOUNT IRON')
# ('USC00215693', 48.3, -95.9833, "MUD LAKE NAT'L WR")
# ('USC00215819', 48.1167, -93.1, 'NETT LAKE')
# ('USC00215838', 45.01, -93.3792, 'NEW HOPE')
# ('USC00215842', 45.305, -94.9392, 'NEW LONDON')
# ('USC00215845', 45.2597, -94.9461, 'NEW LONDON SPICER')
# ('USC00215853', 43.8833, -93.5, 'NEW RICHLAND')
# ('USC00215887', 44.3006, -94.4897, 'NEW ULM 2 SE')
# ('USC00215888', 44.2944, -94.4083, 'NEW ULM 3SE')
# ('USC00215902', 46.5233, -95.3847, 'NEW YORK MILLS')
# ('USC00215912', 48.3333, -96.3333, 'NEWFOLDEN')
# ('USC00215927', 46.4333, -92.5, 'NICKERSON')
# ('USC00215937', 48.1167, -94.3833, 'NORDEN')
# ('USC00215987', 44.4753, -93.1486, 'NORTHFIELD 2 NNE')
# ('USC00215989', 47.8358, -94.2556, 'NORTHOME 3S')
# ('USC00215990', 44.7775, -93.93, 'NORWOOD YOUNG AMER 1 W')
# ('USC00216007', 44.1667, -94.0333, 'NORTH MANKATO')
# ('USC00216008', 44.1708, -94.0386, 'N MANKATO 2')
# ('USC00216148', 47.8333, -95.85, 'OKLEE')
# ('USC00216152', 44.7628, -94.9297, 'OLIVIA 3E')
# ('USC00216166', 46.0678, -93.6667, 'ONAMIA RS')
# ('USC00216210', 48.0333, -92.9167, 'ORR 5 SW')
# ('USC00216211', 48.0508, -92.7636, 'ORR 3E')
# ('USC00216212', 48.05, -93.1, 'ORR 13 W')
# ('USC00216213', 48.0553, -92.8425, 'ORR')
# ('USC00216224', 45.3, -96.45, 'ORTONVILLE')
# ('USC00216225', 45.3092, -96.4292, 'ORTONVILLE 1N')
# ('USC00216228', 46.2153, -96.1781, 'ORWELL DAM')
# ('USC00216233', 45.85, -95.1833, 'OSAKIS')
# ('USC00216276', 46.4144, -95.5464, 'OTTERTAIL')
# ('USC00216287', 44.0981, -93.2308, 'OWATONNA')
# ('USC00216386', 45.3833, -94.7333, 'PAYNESVILLE')
# ('USC00216405', 46.5689, -96.0894, 'PELICAN RAPIDS')
# ('USC00216479', 45.9667, -94.1, 'PIERZ')
# ('USC00216505', 48.0, -89.7, 'PIGEON RIVER BRG')
# ('USC00216547', 46.6694, -94.1089, 'PINE RVR DAM')
# ('USC00216565', 44.0139, -96.3258, 'PIPESTONE')
# ('USC00216571', 44.1667, -92.1667, 'PLAINVIEW')
# ('USC00216573', 44.0, -94.0, 'PLEASANT MOUND')
# ('USC00216612', 47.2508, -93.5861, 'POKEGAMA DAM')
# ('USC00216644', 44.0167, -93.1333, 'PRATT')
# ('USC00216654', 43.6725, -92.0747, 'PRESTON')
# ('USC00216744', 44.1, -94.1, 'RAPIDAN 2 W')
# ('USC00216777', 44.4, -92.0833, 'READS LANDING')
# ('USC00216787', 47.8878, -96.2658, 'RED LAKE FALLS')
# ('USC00216795', 47.8761, -95.0167, 'RED LAKE INDIAN AGCY')
# ('USC00216817', 44.5711, -92.5283, 'RED WING')
# ('USC00216822', 44.6103, -92.61, 'RED WING DAM 3')
# ('USC00216839', 44.5486, -95.0997, 'REDWOOD FALLS')
# ('USC00216848', 47.05, -93.9, 'REMER')
# ('USC00216849', 47.0622, -93.915, 'REMER #2')
# ('USC00216920', 45.7575, -94.2072, 'RICE')
# ('USC00216929', 46.5381, -93.2844, 'RICE LAKE NWR')
# ('USC00216972', 46.4667, -94.05, 'RIVERTON')
# ('USC00217009', 44.0667, -92.4667, 'ROCHESTER SEWAGE')
# ('USC00217011', 43.9336, -92.4728, 'ROCHESTER AP 2NE')
# ('USC00217012', 43.6556, -96.2058, 'ROCK CO SHERIFF')
# ('USC00217020', 45.0897, -93.74, 'ROCKFORD')
# ('USC00217087', 48.8486, -95.7675, 'ROSEAU')
# ('USC00217107', 44.7167, -93.0981, 'ROSEMOUNT RSCH & OUTREACH CTR')
# ('USC00217149', 46.4808, -96.2869, 'ROTHSAY')
# ('USC00217157', 45.8333, -94.3667, 'ROYALTON 5W')
# ('USC00217184', 43.8053, -91.75, 'RUSHFORD')
# ('USC00217227', 46.7664, -96.6336, 'SABIN 1 ESE')
# ('USC00217277', 43.95, -92.0667, 'ST CHARLES')
# ('USC00217308', 45.3333, -93.3667, 'ST FRANCIS 4 S')
# ('USC00217309', 45.3878, -93.3592, 'ST FRANCIS')
# ('USC00217326', 43.9903, -94.6122, 'ST JAMES WWTP')
# ('USC00217362', 46.1167, -95.8333, 'ST OLAF')
# ('USC00217377', 44.9461, -93.03, 'ST PAUL')
# ('USC00217379', 44.9311, -93.1539, 'ST PAUL 3SW')
# ('USC00217381', 45.0, -93.1667, 'ST PAUL UNIV FARM')
# ('USC00217405', 44.3222, -93.9656, 'ST PETER')
# ('USC00217460', 46.7953, -93.3211, 'SANDY LAKE DAM LIBBY')
# ('USC00217502', 45.5458, -93.7572, 'SANTIAGO 3 E')
# ('USC00217514', 45.75, -94.9167, 'SAUK CTR')
# ('USC00217533', 47.8333, -90.8667, 'SAWBILL')
# ('USC00217554', 47.55, -90.9, 'SCHROEDER')
# ('USC00217573', 44.7667, -93.5, 'SHAKOPEE')
# ('USC00217594', 47.4167, -96.7667, 'SHELLY 4 SE')
# ('USC00217602', 43.6303, -94.7744, 'SHERBURN 3 WSW')
# ('USC00217657', 47.65, -93.0333, 'SIDE LAKE RS')
# ('USC00217738', 44.0, -95.75, 'SLAYTON')
# ('USC00217740', 43.9, -95.8833, 'SLAYTON 9 SW')
# ('USC00217907', 44.2469, -94.9864, 'SPRINGFIELD 1 NW')
# ('USC00217915', 43.5619, -91.6447, 'SPRING GROVE')
# ('USC00217917', 43.6125, -91.6222, 'SPRING GROVE 4N')
# ('USC00217935', 44.9347, -93.6275, 'SPRING PARK')
# ('USC00217937', 47.3, -91.6667, 'SPRUCE LAKE CAMP')
# ('USC00217941', 43.6933, -92.3925, 'SPRING VALLEY')
# ('USC00218011', 47.5667, -92.2, 'STEPHENS MINE')
# ('USC00218025', 44.7344, -94.3425, 'STEWART')
# ('USC00218037', 45.0417, -92.7975, 'STILLWATER 1 SE')
# ('USC00218039', 45.0456, -92.8522, 'STILLWATER 2SW')
# ('USC00218061', 45.5833, -92.8333, 'SUNRISE CITY')
# ('USC00218187', 46.6333, -93.1333, 'TAMARACK')
# ('USC00218191', 46.9581, -95.6547, 'TAMARAC WILDLIFE REF')
# ('USC00218204', 45.4167, -92.65, 'TAYLORS FALLS 1 NE')
# ('USC00218215', 47.3389, -91.1958, 'TETTEGOUCHE SP')
# ('USC00218227', 44.2811, -92.1944, 'THEILMAN 1SSW')
# ('USC00218235', 48.4867, -95.9536, 'THIEF LAKE REFUGE')
# ('USC00218243', 48.0667, -96.1833, 'THIEF RIVER FALLS')
# ('USC00218247', 48.1328, -96.1819, 'THIEF RVR FALLS 2')
# ('USC00218254', 48.2108, -95.2475, 'THORHULT')
# ('USC00218260', 46.0081, -96.465, 'TINTAH 1W')
# ('USC00218280', 47.5681, -90.85, 'TOFTE RS')
# ('USC00218307', 47.8003, -92.2867, 'TOWER DNR')
# ('USC00218311', 47.7817, -92.2783, 'TOWER 2S')
# ('USC00218323', 44.2394, -95.6308, 'TRACY')
# ('USC00218332', 47.95, -95.65, 'TRAIL 12 NNE')
# ('USC00218406', 47.2667, -96.25, 'TWIN VALLEY')
# ('USC00218411', 47.2236, -96.2922, 'TWIN VALLEY 3 SW')
# ('USC00218419', 47.0258, -91.6653, 'TWO HARBORS')
# ('USC00218421', 47.1253, -91.7067, 'TWO HARBORS 7NW')
# ('USC00218429', 44.2781, -96.1281, 'TYLER')
# ('USC00218450', 44.9903, -93.18, 'U OF MN ST PAUL')
# ('USC00218477', 45.0483, -93.0958, 'VADNAIS LAKE')
# ('USC00218520', 44.5075, -95.4108, 'VESTA')
# ('USC00218543', 47.5, -92.55, 'VIRGINIA')
# ('USC00218550', 44.3667, -92.0333, 'WABASHA')
# ('USC00218552', 44.385, -92.0486, 'WABASHA')
# ('USC00218579', 46.3939, -95.1494, 'WADENA 3 S')
# ('USC00218613', 47.2561, -91.7017, 'WALES 2E')
# ('USC00218618', 47.0936, -94.5739, 'WALKER')
# ('USC00218621', 47.0997, -94.5725, 'WALKER RS')
# ('USC00218656', 48.65, -95.75, 'WANNASKA 1 S')
# ('USC00218673', 48.1833, -96.7333, 'WARREN')
# ('USC00218674', 48.1953, -96.7761, 'WARREN WSD')
# ('USC00218675', 48.2, -96.7833, 'WARREN')
# ('USC00218676', 48.1508, -96.6417, 'WARREN 7ESE')
# ('USC00218679', 48.8947, -95.3303, 'WARROAD')
# ('USC00218692', 44.0708, -93.5264, 'WASECA S RSCH & OUTREACH CTR')
# ('USC00218700', 48.2058, -94.4272, 'WASKISH 4NE')
# ('USC00218713', 44.9667, -93.85, 'WATERTOWN')
# ('USC00218729', 45.0228, -95.7897, 'WATSON 1 NE')
# ('USC00218763', 48.6, -94.5167, 'WAYLAND 12 NW')
# ('USC00218774', 44.9742, -93.5067, 'WAYZATA')
# ('USC00218808', 43.7467, -93.7367, 'WELLS')
# ('USC00218822', 44.1333, -92.9167, 'WEST CONCORD')
# ('USC00218832', 45.8, -95.0667, 'WEST UNION')
# ('USC00218907', 45.8081, -96.5042, 'WHEATON')
# ('USC00218939', 47.2833, -92.1833, 'WHITEFACE RSVR')
# ('USC00218941', 45.1667, -93.0, 'WHITE BEAR')
# ('USC00218947', 45.8622, -96.5653, 'WHITE ROCK DAM')
# ('USC00218951', 44.0833, -92.0333, 'WHITEWATER STATE PARK')
# ('USC00218986', 45.5231, -92.7489, 'WILD RVR SP')
# ('USC00219001', 45.19, -95.0586, 'WILLMAR 5N')
# ('USC00219004', 45.1078, -95.0358, 'WILLMAR WWTP')
# ('USC00219015', 46.3167, -92.8, 'WILLOW RIVER')
# ('USC00219033', 43.8769, -95.1158, 'WINDOM')
# ('USC00219046', 43.7639, -94.1661, 'WINNEBAGO')
# ('USC00219059', 47.4306, -94.0586, 'WINNIBIGOSHISH DAM')
# ('USC00219067', 44.0422, -91.6364, 'WINONA')
# ('USC00219072', 44.0875, -91.6703, 'WINONA DAM 5 A')
# ('USC00219077', 44.0333, -91.6833, 'WINONA 3 SW')
# ('USC00219085', 44.9511, -94.0628, 'WINSTED')
# ('USC00219093', 44.5333, -94.3667, 'WINTHROP')
# ('USC00219101', 47.9333, -91.7667, 'WINTON PWR PLT')
# ('USC00219134', 47.45, -91.2167, 'WOLF RIDGE ELC')
# ('USC00219166', 43.6167, -95.6, 'WORTHINGTON')
# ('USC00219168', 43.6308, -95.6817, 'WORTHINGTON RAD KWOA')
# ('USC00219170', 43.645, -95.5803, 'WORTHINGTON 2 NNE')
# ('USC00219173', 46.6803, -92.9542, 'WRIGHT 3 E')
# ('USC00219189', 43.7333, -92.2667, 'WYKOFF NEAR')
# ('USC00219201', 45.3333, -93.0, 'WYOMING')
# ('USC00219208', 44.8056, -94.0167, 'YOUNG AMERICA 1SW')
# ('USC00219231', 44.2853, -92.4311, 'ZUMBRO FALLS')
# ('USC00219235', 44.2833, -92.4167, 'ZUMBRO FALLS 1 SE')
# ('USC00219237', 44.3033, -92.4044, 'ZUMBRO FALLS 2NE')
# ('USC00219249', 44.2992, -92.6661, 'ZUMBROTA')
# ('USR0000MAGA', 48.5, -95.87, 'AGASSIZ MINNESOTA')
# ('USR0000MBAU', 48.6703, -94.6172, 'BAUDETTE MINNESOTA')
# ('USR0000MBDA', 46.8608, -94.7258, 'BADOURA MINNESOTA')
# ('USR0000MBEM', 47.5033, -94.9281, 'BEMIDJI MINNESOTA')
# ('USR0000MBRN', 46.4006, -94.1272, 'BRAINERD MINNESOTA')
# ('USR0000MCLK', 47.3778, -94.615, 'CASS LAKE MINNESOTA')
# ('USR0000MCSA', 45.3028, -93.1011, 'CARLOS AVERY MINNESOTA')
# ('USR0000MDET', 46.8489, -95.8464, 'DETROIT LAKES MINNESOTA')
# ('USR0000MEFF', 47.7794, -93.6461, 'EFFIE MINNESOTA')
# ('USR0000MELY', 47.8833, -91.8667, 'ELY MINNESOTA')
# ('USR0000MFER', 47.9461, -91.4947, 'FERNBERG MINNESOTA')
# ('USR0000MHIB', 47.3919, -92.8347, 'HIBBING MINNESOTA')
# ('USR0000MHIL', 47.0375, -93.6042, 'HILL CITY MINNESOTA')
# ('USR0000MISA', 47.6303, -91.4083, 'ISABELLA MINNESOTA')
# ('USR0000MITA', 47.24, -95.19, 'ITASCA MINNESOTA')
# ('USR0000MKAB', 48.4417, -93.05, 'KABNAM MINNESOTA')
# ('USR0000MKLL', 47.9425, -94.455, 'KELLIHER MINNESOTA')
# ('USR0000MLTF', 45.9514, -94.3444, 'LITTLE FALLS MINNESOTA')
# ('USR0000MLTT', 48.3894, -93.5642, 'LITTLEFORK MINNESOTA')
# ('USR0000MMEA', 48.1197, -92.1589, 'MEANDER MINNESOTA')
# ('USR0000MMLK', 46.4203, -92.8008, 'MOOSE LAKE MINNESOTA')
# ('USR0000MMOR', 45.89, -93.2697, 'MORA MINNESOTA')
# ('USR0000MORR', 48.0189, -92.8572, 'ORR MINNESOTA')
# ('USR0000MROS', 48.85, -95.7, 'ROSEAU MINNESOTA')
# ('USR0000MSAG', 46.8436, -92.4617, 'SAGINAW MINNESOTA')
# ('USR0000MSEA', 48.1, -90.9, 'SEAGULL MINNESOTA')
# ('USR0000MSHE', 45.5325, -93.7503, 'SHERBURNE MINNESOTA')
# ('USW00004994', 48.3056, -95.8744, 'GOODRIDGE 12 NNW')
# ('USW00014910', 45.8678, -95.3942, 'ALEXANDRIA MUNI AP')
# ('USW00014913', 46.8369, -92.2097, 'DULUTH')
# ('USW00014918', 48.5614, -93.3981, 'INTL FALLS INTL AP')
# ('USW00014922', 44.8831, -93.2289, 'MINNEAPOLIS/ST PAUL AP')
# ('USW00014925', 43.9042, -92.4917, 'ROCHESTER INTL AP')
# ('USW00014926', 45.5433, -94.0514, 'ST CLOUD RGNL AP')
# ('USW00014927', 44.9319, -93.0556, 'ST PAUL DOWNTOWN AP')
# ('USW00014928', 45.1167, -95.0833, 'WILLMAR AP')
# ('USW00014947', 44.8833, -93.2167, 'MINNEAPOLIS NAS')
# ('USW00014992', 44.5483, -95.0803, 'REDWOOD FALLS MUNI AP')
# ('USW00054932', 46.1136, -92.9936, 'SANDSTONE 6 W')
# ('USW00054936', 45.55, -94.1333, 'ST CLOUD STATE CLG')
# ('USW00094909', 46.8333, -92.1833, 'DULUTH WILIAMSON JOH')
# ('USW00094931', 47.3864, -92.8389, 'HIBBING CHISHOLM HIBBING AP')
# ('USW00094938', 46.4047, -94.1308, 'BRAINERD CROW WING CO AP')
# ('USW00094960', 45.0619, -93.3508, 'MPLS CRYSTAL AP')
# ('USW00094961', 48.7167, -94.6, 'BAUDETTE INTL AP')
# ('USW00094963', 44.8322, -93.4706, 'MPLS FLYING CLOUD AP')
# ('USW00094967', 46.9006, -95.0678, 'PARK RAPIDS MUNI AP')
# ('USW00094992', 47.7472, -90.3444, 'GRAND MARAIS')

# %% [markdown]
# # Load the Inventory Table

# %% [raw]
# VII. FORMAT OF "ghcnd-inventory.txt"
#
# ------------------------------
# Variable   Columns   Type
# ------------------------------
# ID            1-11   Character
# LATITUDE     13-20   Real
# LONGITUDE    22-30   Real
# ELEMENT      32-35   Character
# FIRSTYEAR    37-40   Integer
# LASTYEAR     42-45   Integer
# ------------------------------

# %%
inventory_file = os.path.join(ghcn.path, ghcn.files['GHCN_INVENTORY'])
inventory_colspecs = [(0,12), (12,21), (21, 31), (31,36), (36,41), (41,45)]
inventory_colnames = ["station_id", "latitude", "longitude", "element", "first_year", "last_year"]
inventory_df = pd.read_fwf(inventory_file, colspecs=inventory_colspecs, header=None,
                          names=inventory_colnames)
inventory_df.head()
# Out:
#     station_id  latitude  longitude element  first_year  last_year
# 0  ACW00011604   17.1167   -61.7833    TMAX        1949       1949
# 1  ACW00011604   17.1167   -61.7833    TMIN        1949       1949
# 2  ACW00011604   17.1167   -61.7833    PRCP        1949       1949
# 3  ACW00011604   17.1167   -61.7833    SNOW        1949       1949
# 4  ACW00011604   17.1167   -61.7833    SNWD        1949       1949

# %%
# Save our work to this point in .csv files
stations_df.to_csv(os.path.join(ghcn.path, "stations.csv"))
inventory_df.to_csv(os.path.join(ghcn.path, "inventory.csv"))

# %%
# Iterate over the rows and add to the table
for row in inventory_df.itertuples():
    inventory = Inventory(station_id = row.station_id,
                          element = row.element,
                          first_year = row.first_year,
                          last_year = row.last_year)
    session.add(inventory)
    session.commit()

# %% [markdown]
# # Query the New Database

# %%
items = session.query(Inventory.station_id, Inventory.element, Inventory.first_year, Inventory.last_year).limit(5).all()
for item in items:
    print(item)
# Out:
# ('ACW00011604', 'TMAX', 1949, 1949)
# ('ACW00011604', 'TMIN', 1949, 1949)
# ('ACW00011604', 'PRCP', 1949, 1949)
# ('ACW00011604', 'SNOW', 1949, 1949)
# ('ACW00011604', 'SNWD', 1949, 1949)

# %% [markdown]
# # Pass Through Queries - SQL statements passed through to the database

# %%
sql_query = """
SELECT station_id, first_year, last_year 
FROM inventory
WHERE element == 'SNWD'
ORDER By station_id
"""
query_return = pd.read_sql_query(sql_query, engine)
print(query_return.shape)
query_return.head()
# Out:
# (58166, 3)
#     station_id  first_year  last_year
# 0  ACW00011604        1949       1949
# 1  ACW00011647        1957       1970
# 2  AF000040930        1982       1992
# 3  AFM00040938        1982       2019
# 4  AFM00040948        1974       2018

# %%
sql_query = """
SELECT * FROM stations
WHERE country_id = 'US'
"""
query_return = pd.read_sql_query(sql_query, engine)
print(query_return.shape)
query_return.head()
# Out:
# (60787, 10)
#     station_id  latitude  longitude  elevation country_id state_id  \
# 0  US009052008   43.7333   -96.6333      482.0         US       SD
# 1  US10RMHS145   40.5268  -105.1113     1569.1         US       CO
# 2  US10adam001   40.5680   -98.5069      598.0         US       NE
# 3  US10adam002   40.5093   -98.5493      601.1         US       NE
# 4  US10adam003   40.4663   -98.6537      615.1         US       NE
#
#                             name   gsn   hcn  wmo
# 0  SIOUX FALLS (ENVIRON. CANADA)  None  None  NaN
# 1                   RMHS 1.6 SSW  None  None  NaN
# 2                  JUNIATA 1.5 S  None  None  NaN
# 3                JUNIATA 6.0 SSW  None  None  NaN
# 4                HOLSTEIN 0.1 NW  None  None  NaN

# %%
def make_sql_query_string(element, first_year, last_year):
    sql_query = f"SELECT station_id FROM inventory WHERE element = {element} AND first_year >= {first_year} AND last_year <= {last_year}"
    return sql_query

# %%
make_sql_query_string("'SNWD'", 1949, 2019)
# Out:
# "SELECT station_id FROM inventory WHERE element = 'SNWD' AND first_year >= 1949 AND last_year <= 2019"

# %%
query_return = pd.read_sql_query(make_sql_query_string("'PRCP'", 1970, 2019), engine)
print(query_return.shape)
query_return.head()
# Out:
# (56547, 1)
#     station_id
# 0  AEM00041194
# 1  AEM00041217
# 2  AEM00041218
# 3  AF000040930
# 4  AFM00040938

# %%
from sqlalchemy import and_
t = session.query(
    Inventory.station_id
).filter(Inventory.first_year <= 2010).filter(Inventory.last_year == 2019).filter(Inventory.element == 'SNWD').subquery('t')

query = session.query(Stations).filter(and_(
    Stations.country_id == 'US',
    Stations.state_id == 'MN',
    Stations.station_id == t.c.station_id
)
)

print(query.count())
for item in query:
    print(item.station_id, item.name, item.state.name)
# Out:
# 179
# US1MNAA0004 SAINT FRANCIS 4.0 E MINNESOTA
# US1MNBW0001 SPRINGFIELD 1.7 NNW MINNESOTA
# US1MNCN0001 CARLTON 5.6 NE MINNESOTA
# US1MNCP0001 MONTEVIDEO 0.4 SSW MINNESOTA
# US1MNCS0001 PILLAGER 5.1 N MINNESOTA
# US1MNCV0001 CARVER 0.7 W MINNESOTA
# US1MNCY0001 MOORHEAD 2.0 N MINNESOTA
# US1MNDK0014 INVER GROVE HEIGHTS 1.3 ENE MINNESOTA
# US1MNDK0015 BURNSVILLE 3.0 NE MINNESOTA
# US1MNGH0003 LAKE CITY 1.2 NNW MINNESOTA
# US1MNHN0006 LONG LAKE 0.2 WSW MINNESOTA
# US1MNHN0009 MINNEAPOLIS 3.0 NNW MINNESOTA
# US1MNHN0014 MINNETRISTA 1.5 SSE MINNESOTA
# US1MNHN0017 EDEN PRAIRIE 3.3 WSW MINNESOTA
# US1MNHN0019 EDINA 1.3 SW MINNESOTA
# US1MNHN0022 MINNEAPOLIS 3.3 SW MINNESOTA
# US1MNKB0003 BROOK PARK 9.0 WNW MINNESOTA
# US1MNKD0001 BELGRADE 8.0 ESE MINNESOTA
# US1MNLY0002 MARSHALL 0.6 S MINNESOTA
# US1MNOT0003 BATTLE LAKE 2S MINNESOTA
# US1MNPK0002 ERSKINE 7.6 SW MINNESOTA
# US1MNRC0001 MONTGOMERY 3.2 ENE MINNESOTA
# US1MNRM0002 NORTH SAINT PAUL 1.0 NNW MINNESOTA
# US1MNRM0005 ROSEVILLE 1.4 SSE MINNESOTA
# US1MNRM0015 ROSEVILLE 2.1 NW MINNESOTA
# US1MNSC0002 PRIOR LAKE 2.0 W MINNESOTA
# US1MNSE0002 OWATONNA 0.8 E MINNESOTA
# US1MNSE0003 ELLENDALE 0.3 SW MINNESOTA
# US1MNWR0008 SAINT MICHAEL 1.3 E MINNESOTA
# USC00210075 ALBERT LEA 3 SE MINNESOTA
# USC00210146 ALTURA 5W MINNESOTA
# USC00210157 AMBOY MINNESOTA
# USC00210190 ANDOVER 1N MINNESOTA
# USC00210252 ARGYLE MINNESOTA
# USC00210287 ARTICHOKE LAKE 1 E MINNESOTA
# USC00210355 AUSTIN WASTE WTP FACILITY MINNESOTA
# USC00210387 BABBITT MINNESOTA
# USC00210643 BEMIDJI MINNESOTA
# USC00210667 BENSON MINNESOTA
# USC00210746 BIG FALLS MINNESOTA
# USC00210809 BLACKDUCK MINNESOTA
# USC00210855 BLUE EARTH 1S MINNESOTA
# USC00210939 BRAINERD MINNESOTA
# USC00210981 BRICELYN MINNESOTA
# USC00210989 BRIMSON 2S MINNESOTA
# USC00211063 BROWNS VALLEY MINNESOTA
# USC00211065 BROWNTON WWTP MINNESOTA
# USC00211074 BRUNO 7ENE MINNESOTA
# USC00211198 CALEDONIA MINNESOTA
# USC00211227 CAMBRIDGE 5ESE MINNESOTA
# USC00211250 CAMP NORRIS DNR MINNESOTA
# USC00211263 CANBY MINNESOTA
# USC00211310 CARLOS 2 WSW MINNESOTA
# USC00211374 CASS LAKE MINNESOTA
# USC00211448 CHANHASSEN WSFO MINNESOTA
# USC00211630 CLOQUET MINNESOTA
# USC00211691 COLLEGEVILLE ST JOHN'S MINNESOTA
# USC00211771 COOK 8NE MINNESOTA
# USC00211840 COTTON MINNESOTA
# USC00211891 CROOKSTON NW EXP STN MINNESOTA
# USC00212023 DASSEL 3SE MINNESOTA
# USC00212038 DAWSON MINNESOTA
# USC00212088 DELANO MINNESOTA
# USC00212146 DETROIT LAKES 12E MINNESOTA
# USC00212486 ELGIN 2SSW MINNESOTA
# USC00212500 ELK RVR MINNESOTA
# USC00212555 ELY 25E MINNESOTA
# USC00212576 EMBARRASS MINNESOTA
# USC00212645 EVELETH WWTP MINNESOTA
# USC00212721 FARIBAULT MINNESOTA
# USC00212842 FLOODWOOD 3 NE MINNESOTA
# USC00212916 FOSSTON 1 E MINNESOTA
# USC00213076 GAYLORD MINNESOTA
# USC00213104 GEORGETOWN 1 E MINNESOTA
# USC00213282 GRAND MARAIS MINNESOTA
# USC00213290 GRAND MEADOW MINNESOTA
# USC00213296 GRAND PORTAGE MINNESOTA
# USC00213303 GRAND RPDS FOREST LAB MINNESOTA
# USC00213311 GRANITE FALLS MINNESOTA
# USC00213411 GULL LAKE DAM MINNESOTA
# USC00213417 GUNFLINT LAKE 10 NW MINNESOTA
# USC00213455 HALLOCK MINNESOTA
# USC00213463 HALSTAD MINNESOTA
# USC00213520 HARMONY MINNESOTA
# USC00213567 HASTINGS DAM 2 MINNESOTA
# USC00214008 INDUS 3 W MINNESOTA
# USC00214077 ISABELLA 14W MINNESOTA
# USC00214093 ISLAND LAKE 4E MINNESOTA
# USC00214103 ISLE 12N MINNESOTA
# USC00214106 ITASCA UNIV OF MINN MINNESOTA
# USC00214176 JORDAN 1SSW MINNESOTA
# USC00214191 KABETOGAMA MINNESOTA
# USC00214233 KELLIHER MINNESOTA
# USC00214373 KIMBALL 3N MINNESOTA
# USC00214418 LA CRESCENT DAM 7 MINNESOTA
# USC00214438 LAKE CITY MINNESOTA
# USC00214453 LAKEFIELD 2NE MINNESOTA
# USC00214534 LAKE WILSON MINNESOTA
# USC00214546 LAMBERTON SW RSCH & OUTREACH C MINNESOTA
# USC00214652 LEECH LAKE MINNESOTA
# USC00214692 LESTER PRAIRIE 2S MINNESOTA
# USC00214778 LITCHFIELD MINNESOTA
# USC00214861 LONG PRAIRIE MINNESOTA
# USC00214884 LOWER ST ANTHONY FALLS MINNESOTA
# USC00214994 MADISON WWTP MINNESOTA
# USC00215204 MARSHALL MINNESOTA
# USC00215325 MELROSE MINNESOTA
# USC00215392 MILACA MINNESOTA
# USC00215400 MILAN 1NW MINNESOTA
# USC00215482 MINNEOTA MINNESOTA
# USC00215488 MINNESOTA CITY DAM 5 MINNESOTA
# USC00215563 MONTEVIDEO 1SW MINNESOTA
# USC00215598 MOOSE LAKE 1 SSE MINNESOTA
# USC00215615 MORA MINNESOTA
# USC00215638 MORRIS W CNTRL RSCH & OUTREACH MINNESOTA
# USC00215838 NEW HOPE MINNESOTA
# USC00215902 NEW YORK MILLS MINNESOTA
# USC00215989 NORTHOME 3S MINNESOTA
# USC00216166 ONAMIA RS MINNESOTA
# USC00216211 ORR 3E MINNESOTA
# USC00216225 ORTONVILLE 1N MINNESOTA
# USC00216276 OTTERTAIL MINNESOTA
# USC00216287 OWATONNA MINNESOTA
# USC00216547 PINE RVR DAM MINNESOTA
# USC00216565 PIPESTONE MINNESOTA
# USC00216612 POKEGAMA DAM MINNESOTA
# USC00216654 PRESTON MINNESOTA
# USC00216787 RED LAKE FALLS MINNESOTA
# USC00216795 RED LAKE INDIAN AGCY MINNESOTA
# USC00216817 RED WING MINNESOTA
# USC00216822 RED WING DAM 3 MINNESOTA
# USC00216839 REDWOOD FALLS MINNESOTA
# USC00216920 RICE MINNESOTA
# USC00217011 ROCHESTER AP 2NE MINNESOTA
# USC00217020 ROCKFORD MINNESOTA
# USC00217107 ROSEMOUNT RSCH & OUTREACH CTR MINNESOTA
# USC00217149 ROTHSAY MINNESOTA
# USC00217184 RUSHFORD MINNESOTA
# USC00217326 ST JAMES WWTP MINNESOTA
# USC00217405 ST PETER MINNESOTA
# USC00217460 SANDY LAKE DAM LIBBY MINNESOTA
# USC00217502 SANTIAGO 3 E MINNESOTA
# USC00217602 SHERBURN 3 WSW MINNESOTA
# USC00217941 SPRING VALLEY MINNESOTA
# USC00218039 STILLWATER 2SW MINNESOTA
# USC00218191 TAMARAC WILDLIFE REF MINNESOTA
# USC00218227 THEILMAN 1SSW MINNESOTA
# USC00218254 THORHULT MINNESOTA
# USC00218311 TOWER 2S MINNESOTA
# USC00218323 TRACY MINNESOTA
# USC00218419 TWO HARBORS MINNESOTA
# USC00218421 TWO HARBORS 7NW MINNESOTA
# USC00218450 U OF MN ST PAUL MINNESOTA
# USC00218477 VADNAIS LAKE MINNESOTA
# USC00218552 WABASHA MINNESOTA
# USC00218618 WALKER MINNESOTA
# USC00218692 WASECA S RSCH & OUTREACH CTR MINNESOTA
# USC00218700 WASKISH 4NE MINNESOTA
# USC00218808 WELLS MINNESOTA
# USC00218907 WHEATON MINNESOTA
# USC00218947 WHITE ROCK DAM MINNESOTA
# USC00218986 WILD RVR SP MINNESOTA
# USC00219001 WILLMAR 5N MINNESOTA
# USC00219033 WINDOM MINNESOTA
# USC00219046 WINNEBAGO MINNESOTA
# USC00219059 WINNIBIGOSHISH DAM MINNESOTA
# USC00219072 WINONA DAM 5 A MINNESOTA
# USC00219134 WOLF RIDGE ELC MINNESOTA
# USC00219170 WORTHINGTON 2 NNE MINNESOTA
# USC00219173 WRIGHT 3 E MINNESOTA
# USC00219249 ZUMBROTA MINNESOTA
# USW00014913 DULUTH MINNESOTA
# USW00014918 INTL FALLS INTL AP MINNESOTA
# USW00014922 MINNEAPOLIS/ST PAUL AP MINNESOTA
# USW00014925 ROCHESTER INTL AP MINNESOTA
# USW00014926 ST CLOUD RGNL AP MINNESOTA
# USW00014992 REDWOOD FALLS MUNI AP MINNESOTA
# USW00094938 BRAINERD CROW WING CO AP MINNESOTA
# USW00094967 PARK RAPIDS MUNI AP MINNESOTA

# %%
def find_stations_with(session, element, first_year=None, last_year=None):
    """
    Args:  
        element: one of the elements in the inventory table.
        first_year: the earliest year that must be included.  If None, we do not filter on first_year
        last_year: the latest year that must be included.  If None, we do not filter on last_year
    """
    
    if first_year:
        if last_year: 
            t = session.query(
                Inventory.station_id,
                Inventory.first_year,
                Inventory.last_year
            ).filter(Inventory.first_year <= first_year)\
            .filter(Inventory.last_year >= last_year)\
            .filter(Inventory.element == element).subquery('t')
        else:
            t = session.query(
                Inventory.station_id,
                Inventory.first_year, 
                Inventory.last_year
            ).filter(Inventory.first_year <= first_year)\
            .filter(Inventory.element == element).subquery('t')
    else:
        if last_year: 
            t = session.query(
                Inventory.station_id,
                Inventory.first_year, 
                Inventory.last_year
            ).filter(Inventory.last_year >= last_year)\
            .filter(Inventory.element == element).subquery('t')
        else:
            t = session.query(
                Inventory.station_id,
                Inventory.first_year, 
                Inventory.last_year
            ).filter(Inventory.element == element).subquery('t')
        

    query = session.query(Stations).filter(
        Stations.station_id == t.c.station_id
    )

    return pd.read_sql(query.statement, session.bind)

# %%
rain_1970_1980_df = find_stations_with(session, 'PRCP', 1970, 1980)
print(rain_1970_1980_df.shape)
rain_1970_1980_df.head()

# %%
any_rain_df = find_stations_with(session, 'PRCP')
print(any_rain_df.shape)
any_rain_df.head()
